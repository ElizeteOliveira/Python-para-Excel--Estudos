# %%
import pandas as pd

# %%
# Lista de arquivos Excel a serem processados
arquivos_entrada = [
    r'C:\Users\E1180062\Downloads\Análise de Orçamento\Dados_Combinados_JAN_PHB.xlsx',
    r'C:\Users\E1180062\Downloads\Análise de Orçamento\Dados_Combinados_FEV_PHB.xlsx',
    r'C:\Users\E1180062\Downloads\Análise de Orçamento\Dados_Combinados_MAR_PHB.xlsx',
    r'C:\Users\E1180062\Downloads\Análise de Orçamento\Dados_Combinados_ABR_PHB.xlsx',
    r'C:\Users\E1180062\Downloads\Análise de Orçamento\Dados_Combinados_MAI_PHB.xlsx'
]

# %%
def processar_arquivo(arquivo_entrada):
    try:
        # Leitura do arquivo Excel
        df = pd.read_excel(arquivo_entrada)
        print(f"Arquivo {arquivo_entrada} lido com sucesso!")
        
        # Adiciona coluna com o nome do arquivo
        df['Origem'] = arquivo_entrada
        
        # Verificação da leitura e contagem de frequência
        try:
            frequencia_servico = df['DESCRIÇÃO DE SERVIÇO'].value_counts()
            print("Frequência dos serviços:\n", frequencia_servico)
        except KeyError as e:
            print(f"Erro: a coluna {e} não foi encontrada no DataFrame.")
        
        # Filtragem das linhas com palavras-chave
        criterios = ['chave fusivel','chave faca','chave by-pass', 'para-raios', 'poste', 'ramal', 'cabo', 'religador']
        try:
            mascara1 = df['DESCRIÇÃO DE SERVIÇO'].str.contains('|'.join(criterios), case=False, na=False)
            df_filtrado = df[mascara1]
            print(f"Arquivo filtrado {arquivo_entrada}:")
            display(df_filtrado)
        except KeyError as e:
            print(f"Erro: a coluna {e} não foi encontrada no DataFrame.")
        
        # Contagem de frequência dos serviços filtrados
        if not df_filtrado.empty:
            frequencia_servico_filtrado = df_filtrado['DESCRIÇÃO DE SERVIÇO'].value_counts()
            print("Frequência dos serviços filtrados:\n", frequencia_servico_filtrado)
        else:
            print("Nenhum dado filtrado encontrado.")
        
        # Exibição dos nomes das colunas após a filtragem 
        if not df_filtrado.empty:
            print("\nNomes das colunas após a filtragem:")
            print(df_filtrado.columns)
        
        # Exclusão de colunas desnecessárias
        excluir_colunas = ['PEP&ORDEM&SERVIÇO','PI','EQUIPE','TIPO','TIPO DE MEDIÇÃO','Tipo de Medição','PEP IV NÍVEL','STATUS PEP', 'UN.','PU', 'OBS EQTL','Unnamed: 44', 'TIPO DE MEDIÇÃO.1',
                          'STATUS PEP\n(ALTERADO)','ORDEM/DIAGRAMA','STATUS ORDEM/DIAGRAMA','NOTA PROJ', 'Unnamed: 41', 'Unnamed: 45', 'TIPO DE MEDIÇÃO.1',
                          'ÁREA                                     DISTRIBUIDORA','CADERNO','ITEM','CÓD. SERVIÇO','CÓD. SERVIÇO&ITEM', 'TIPO DE MEDIÇÃO.2',
                          'QUANT / KM','QUANT / KM.1','TIPO DE MEDIÇÃO','PERÍODO DE MEDIÇÃO','TÉCNICO OBRA','NDS ', 'Unnamed: 42', 'Área Resp (DISTRIBUIDORA)',
                          'SUPERVISOR/SOLICITANTE','MUNICÍPIO','MUNICIPIO','DESLOCAMENTO\nDE','DESLOCAMENTO\nPARA', 'Unnamed: 43', 'Unnamed: 23', 'CONTROLE\n(DADOS ENGENHARIA)'
                          'EQUIPE','ESTRUTURA','CONTROLE\n(dados Engenharia)','NOTA\nRECLAMAÇÃO\n(NR)', 'NOTA\nRECLAMAÇÃO / OCORRÊNCIA\n(NR / OC)',
                          'PEDIDO','OBS PARCEIRA','REGIONAL','MEDIÇÃO','OBRA ','OBRA','TÉCNICO RESPONSÁVEL','Área Resp\n(DISTRIBUIDORA)','TIPO DE MEDIÇÃO.3']
        try:
            df_final = df_filtrado.drop(columns=excluir_colunas, errors='ignore')
            print("Colunas excluídas com sucesso!")
        except Exception as e:
            print(f"Erro ao excluir colunas: {e}")
        
        return df_final
    except Exception as e:
        print(f"Erro ao processar o arquivo {arquivo_entrada}: {e}")
        return pd.DataFrame()

# %%
# Lista para armazenar DataFrames filtrados
todos_dados_filtrados = []

for arquivo in arquivos_entrada:
    df_processado = processar_arquivo(arquivo)
    if not df_processado.empty:
        todos_dados_filtrados.append(df_processado)

# Unificação dos DataFrames filtrados
if todos_dados_filtrados:
    df_unificado = pd.concat(todos_dados_filtrados, ignore_index=True)
    print("Dados unificados com sucesso!")
else:
    df_unificado = pd.DataFrame()
# Out:
# Arquivo C:\Users\E1180062\Downloads\Análise de Orçamento\Dados_Combinados_JAN_PHB.xlsx lido com sucesso!
# Frequência dos serviços:
#  DESCRIÇÃO DE SERVIÇO
# INST COBERTURA PROVISORIA CONDUTOR 4P LV    114
# INST JUMPER OU PASSAGEM NEUTRO 4P LV         67
# PODAR OU CORTAR ARVORE AREA URBANA LM        33
# TENSIONAR CONDUTOR NU 4P LV                  29
# RETIRAR CHAVE FUSIVEL 4P LV                  29
#                                            ...
# INSTALAR ESTRUT PRI CRUZETA SIMPLES LM        1
# INST ISOLADOR PINO OU PINO 3P LV              1
# RETIRAR CHAVE FUSIVEL 15KV 4P LV              1
# INSTALAR ESTRUTURA SECUNDARIA CRUZETA LM      1
# INSTALAR PARA-RAIOS 4P LV                     1
# Name: count, Length: 68, dtype: int64
# Arquivo filtrado C:\Users\E1180062\Downloads\Análise de Orçamento\Dados_Combinados_JAN_PHB.xlsx:
#         PEP&ORDEM&SERVIÇO  PI  TIPO TIPO DE MEDIÇÃO TIPO DE MEDIÇÃO.1  \
# 3                     NaN NaN   NaN         Custeio           Custeio
# 5                     NaN NaN   NaN         Custeio           Custeio
# 84   60007236065033000146 NaN   NaN         Custeio           Custeio
# 85   60007236065033000132 NaN   NaN         Custeio           Custeio
# 91   60007226095033000146 NaN   NaN         Custeio           Custeio
# ..                    ...  ..   ...             ...               ...
# 581  60007360265033000132 NaN   NaN         Custeio         MED ÚNICA
# 590  60007360265033000146 NaN   NaN         Custeio         MED ÚNICA
# 593  60007360265033000132 NaN   NaN         Custeio         MED ÚNICA
# 597  60007331285033000146 NaN   NaN         Custeio         MED ÚNICA
# 598  60007331285033000132 NaN   NaN         Custeio         MED ÚNICA
#
#      PEP IV NÍVEL  STATUS PEP STATUS PEP\n(ALTERADO)  ORDEM/DIAGRAMA  \
# 3             NaN         NaN                      /    6.000733e+09
# 5             NaN         NaN                      /    6.000733e+09
# 84            NaN         NaN                      /    6.000724e+09
# 85            NaN         NaN                      /    6.000724e+09
# 91            NaN         NaN                      /    6.000723e+09
# ..            ...         ...                    ...             ...
# 581           NaN         NaN                      /    6.000736e+09
# 590           NaN         NaN                      /    6.000736e+09
# 593           NaN         NaN                      /    6.000736e+09
# 597           NaN         NaN                      /    6.000733e+09
# 598           NaN         NaN                      /    6.000733e+09
#
#     STATUS ORDEM/DIAGRAMA  ...   DESLOCAMENTO\nDE DESLOCAMENTO\nPARA  \
# 3                     NaN  ...  CAJUEIRO DA PRAIA  CAJUEIRO DA PRAIA
# 5                     NaN  ...  CAJUEIRO DA PRAIA  CAJUEIRO DA PRAIA
# 84               LIB/ATEC  ...     MATIAS OLIMPIO             BR 222
# 85               LIB/ATEC  ...     MATIAS OLIMPIO             BR 222
# 91               LIB/ATEC  ...       LUIS CORREIA       LUIS CORREIA
# ..                    ...  ...                ...                ...
# 581              LIB/ATEC  ...                NaN                NaN
# 590              LIB/ATEC  ...                NaN                NaN
# 593              LIB/ATEC  ...                NaN                NaN
# 597              LIB/ATEC  ...                NaN                NaN
# 598              LIB/ATEC  ...                NaN                NaN
#
#        EQUIPE  ESTRUTURA  CONTROLE\n(DADOS ENGENHARIA)  \
# 3    TATPAB01        NaN                           NaN
# 5    TATPAB01        NaN                           NaN
# 84   LVPPAB01        NaN                           NaN
# 85   LVPPAB01        NaN                           NaN
# 91   LVLPAB01        NaN                           NaN
# ..        ...        ...                           ...
# 581       NaN        NaN                           NaN
# 590       NaN        NaN                           NaN
# 593       NaN        NaN                           NaN
# 597       NaN        NaN                           NaN
# 598       NaN        NaN                           NaN
#
#      SOLICITAÇÃO DE\nINTERVENÇÃO\n(SI) OBS PARCEIRA  \
# 3                                  NaN          NaN
# 5                                  NaN          NaN
# 84                              344602          NaN
# 85                              344602          NaN
# 91                                 NaN          NaN
# ..                                 ...          ...
# 581                          NDS 2-484          NaN
# 590                          NDS 2-527          NaN
# 593                          NDS 2-527          NaN
# 597                          NDS 2-555          NaN
# 598                          NDS 2-555          NaN
#
#                                               REGIONAL  MEDIÇÃO  \
# 3                                                   ok      NaN
# 5                                                   ok      NaN
# 84   PRECISO DE EVIDÊNCIAS E BAIXA DE ANOMALIAS NO MAN      NaN
# 85   PRECISO DE EVIDÊNCIAS E BAIXA DE ANOMALIAS NO MAN      NaN
# 91                                                  OK      NaN
# ..                                                 ...      ...
# 581                                                 OK      NaN
# 590                                                 OK      NaN
# 593                                                 OK      NaN
# 597                                                 OK      NaN
# 598                                                 OK      NaN
#
#                                                 Origem
# 3    C:\Users\E1180062\Downloads\Análise de Orçamen...
# 5    C:\Users\E1180062\Downloads\Análise de Orçamen...
# 84   C:\Users\E1180062\Downloads\Análise de Orçamen...
# 85   C:\Users\E1180062\Downloads\Análise de Orçamen...
# 91   C:\Users\E1180062\Downloads\Análise de Orçamen...
# ..                                                 ...
# 581  C:\Users\E1180062\Downloads\Análise de Orçamen...
# 590  C:\Users\E1180062\Downloads\Análise de Orçamen...
# 593  C:\Users\E1180062\Downloads\Análise de Orçamen...
# 597  C:\Users\E1180062\Downloads\Análise de Orçamen...
# 598  C:\Users\E1180062\Downloads\Análise de Orçamen...
#
# [99 rows x 39 columns]
# Frequência dos serviços filtrados:
#  DESCRIÇÃO DE SERVIÇO
# RETIRAR CHAVE FUSIVEL 4P LV                 29
# INSTALAR CHAVE FUSIVEL 4P LV                24
# RETIRAR CHAVE FACA 4P LV                    11
# INST CHAVE FACA 4P LV                       10
# REAPERTAR E REGULAR CHAVE BY-PASS 4P LV      9
# RETIRAR PARA-RAIOS 4P LV                     3
# INST CHAVE BY-PASS 4P LV                     3
# INSTALAR CHAVE FUSIVEL 15KV LM               1
# TURMA LV INST POSTE EST SUSP 2-3F  4P LV     1
# RETIRAR CHAVE FUSIVEL RELIGADORA 4P LV       1
# RETIRAR POSTE 10 A 14M FECHAR CAVA LM        1
# RETIRAR POSTE 7 A 9M FECHAR CAVA LM          1
# RETIRAR CHAVE FUSIVEL  LM                    1
# SUBSTITUIR CHAVE FUSIVEL 4P LV               1
# APRUMAR POSTE RD LM                          1
# RETIRAR CHAVE FUSIVEL 15KV 4P LV             1
# INSTALAR PARA-RAIOS 4P LV                    1
# Name: count, dtype: int64
#
# Nomes das colunas após a filtragem:
# Index(['PEP&ORDEM&SERVIÇO', 'PI', 'TIPO', 'TIPO DE MEDIÇÃO',
#        'TIPO DE MEDIÇÃO.1', 'PEP IV NÍVEL', 'STATUS PEP',
#        'STATUS PEP\n(ALTERADO)', 'ORDEM/DIAGRAMA', 'STATUS ORDEM/DIAGRAMA',
#        'NOTA PROJ', 'DESCR. DA OBRA', 'CADERNO', 'ITEM', 'CÓD. SERVIÇO',
#        'CÓD. SERVIÇO&ITEM', 'DESCRIÇÃO DE SERVIÇO', 'UN.', 'PU', 'QUANT / KM',
#        'VALOR', 'QUANT / KM.1', 'VALOR.1', 'TIPO DE MEDIÇÃO.2',
#        'TIPO DE MEDIÇÃO.3', 'TÉCNICO OBRA', 'SUPERVISOR/SOLICITANTE',
#        'PERÍODO DE MEDIÇÃO', 'DATA DO SERVIÇO', 'DESLOCAMENTO\nDE',
#        'DESLOCAMENTO\nPARA', 'EQUIPE', 'ESTRUTURA',
#        'CONTROLE\n(DADOS ENGENHARIA)', 'SOLICITAÇÃO DE\nINTERVENÇÃO\n(SI)',
#        'OBS PARCEIRA', 'REGIONAL', 'MEDIÇÃO', 'Origem'],
#       dtype='object')
# Colunas excluídas com sucesso!
# Arquivo C:\Users\E1180062\Downloads\Análise de Orçamento\Dados_Combinados_FEV_PHB.xlsx lido com sucesso!
# Frequência dos serviços:
#  DESCRIÇÃO DE SERVIÇO
# INST COBERTURA PROVISORIA CONDUTOR 4P LV    130
# INST JUMPER OU PASSAGEM NEUTRO 4P LV         53
# RETIRAR CHAVE FUSIVEL 4P LV                  30
# REAPERTAR ESTRUTURA PRIMARIA 4P LV           27
# INSTALAR CHAVE FUSIVEL 4P LV                 25
#                                            ...
# SUBSTITUIR EMENDA CONDUTOR NU 3PLV            1
# INST ISOLADOR PINO OU PINO 3P LV              1
# RETIRAR CHAVE FUSIVEL 15KV 4P LV              1
# RETIRAR ISOLADOR PINO OU PINO FL 3P LV        1
# RETIRAR CHAVE FUSIVEL RELIGADORA 4P LV        1
# Name: count, Length: 79, dtype: int64
# Arquivo filtrado C:\Users\E1180062\Downloads\Análise de Orçamento\Dados_Combinados_FEV_PHB.xlsx:
#         PEP&ORDEM&SERVIÇO  PI  TIPO TIPO DE MEDIÇÃO TIPO DE MEDIÇÃO.1  \
# 24                    NaN NaN   NaN         Custeio           Custeio
# 46   60007373705033000146 NaN   NaN         Custeio           Custeio
# 47   60007373705033000132 NaN   NaN         Custeio           Custeio
# 60   60007191295033000146 NaN   NaN         Custeio           Custeio
# 61   60007191295033000132 NaN   NaN         Custeio           Custeio
# ..                    ...  ..   ...             ...               ...
# 637  60007593595033000132 NaN   NaN         Custeio         MED ÚNICA
# 638  60007593595033000157 NaN   NaN         Custeio         MED ÚNICA
# 648  60007429745033000146 NaN   NaN         Custeio         MED ÚNICA
# 650  60007429745033000132 NaN   NaN         Custeio         MED ÚNICA
# 657  60007468545033000148 NaN   NaN         Custeio         MED ÚNICA
#
#     PEP IV NÍVEL  STATUS PEP STATUS PEP\n(ALTERADO)  ORDEM/DIAGRAMA  \
# 24           NaN         NaN                      /      6000744584
# 46           NaN         NaN                      /      6000737370
# 47           NaN         NaN                      /      6000737370
# 60           NaN         NaN                      /      6000719129
# 61           NaN         NaN                      /      6000719129
# ..           ...         ...                    ...             ...
# 637          NaN         NaN                      /      6000759359
# 638          NaN         NaN                      /      6000759359
# 648          NaN         NaN                      /      6000742974
# 650          NaN         NaN                      /      6000742974
# 657          NaN         NaN                      /      6000746854
#
#     STATUS ORDEM/DIAGRAMA  ...          DESLOCAMENTO\nDE  \
# 24                    NaN  ...  RUA VEREADOR ZITO AMARAL
# 46               LIB/ATEC  ...                  PARNAIBA
# 47               LIB/ATEC  ...                  PARNAIBA
# 60               LIB/ATEC  ...                  PEDRO II
# 61               LIB/ATEC  ...                  PEDRO II
# ..                    ...  ...                       ...
# 637              LIB/ATEC  ...                       NaN
# 638              LIB/ATEC  ...                       NaN
# 648              LIB/ATEC  ...                       NaN
# 650              LIB/ATEC  ...                       NaN
# 657              LIB/ATEC  ...                       NaN
#
#            DESLOCAMENTO\nPARA    EQUIPE  ESTRUTURA  \
# 24   RUA VEREADOR ZITO AMARAL  TATPRI01        NaN
# 46                   PARNAIBA  LVLPAB01        NaN
# 47                   PARNAIBA  LVLPAB01        NaN
# 60                   PEDRO II  LVPPAB01        NaN
# 61                   PEDRO II  LVPPAB01        NaN
# ..                        ...       ...        ...
# 637                       NaN        OK        NaN
# 638                       NaN        OK        NaN
# 648                       NaN        OK        NaN
# 650                       NaN        OK        NaN
# 657         FECHAR CHAVE FACA        OK        NaN
#
#      CONTROLE\n(DADOS ENGENHARIA)  SOLICITAÇÃO DE\nINTERVENÇÃO\n(SI)  \
# 24                            NaN                                NaN
# 46                            NaN                                  0
# 47                            NaN                                  0
# 60                            NaN                             346307
# 61                            NaN                             346307
# ..                            ...                                ...
# 637                           NaN                          NDS 2-350
# 638                           NaN                          NDS 2-350
# 648                           NaN                          SI 348622
# 650                           NaN                          SI 348622
# 657                           NaN                          NDS 3-404
#
#     OBS PARCEIRA REGIONAL  MEDIÇÃO  \
# 24           NaN      NaN      NaN
# 46           NaN       OK      NaN
# 47           NaN       OK      NaN
# 60           NaN       OK      NaN
# 61           NaN       OK      NaN
# ..           ...      ...      ...
# 637          NaN       OK      NaN
# 638          NaN       OK      NaN
# 648          NaN       OK      NaN
# 650          NaN       OK      NaN
# 657          NaN       OK      NaN
#
#                                                 Origem
# 24   C:\Users\E1180062\Downloads\Análise de Orçamen...
# 46   C:\Users\E1180062\Downloads\Análise de Orçamen...
# 47   C:\Users\E1180062\Downloads\Análise de Orçamen...
# 60   C:\Users\E1180062\Downloads\Análise de Orçamen...
# 61   C:\Users\E1180062\Downloads\Análise de Orçamen...
# ..                                                 ...
# 637  C:\Users\E1180062\Downloads\Análise de Orçamen...
# 638  C:\Users\E1180062\Downloads\Análise de Orçamen...
# 648  C:\Users\E1180062\Downloads\Análise de Orçamen...
# 650  C:\Users\E1180062\Downloads\Análise de Orçamen...
# 657  C:\Users\E1180062\Downloads\Análise de Orçamen...
#
# [110 rows x 39 columns]
# Frequência dos serviços filtrados:
#  DESCRIÇÃO DE SERVIÇO
# RETIRAR CHAVE FUSIVEL 4P LV                 30
# INSTALAR CHAVE FUSIVEL 4P LV                25
# RETIRAR PARA-RAIOS 4P LV                     9
# RETIRAR CHAVE FACA 4P LV                     7
# SUBSTITUIR CHAVE FUSIVEL 4P LV               7
# INSTALAR PARA-RAIOS 4P LV                    6
# INST CHAVE FACA 4P LV                        5
# REAPERTAR E REGULAR CHAVE BY-PASS 4P LV      3
# RETIRAR POSTE 10 A 14M FECHAR CAVA LM        2
# RETIRAR POSTE 7 A 9M FECHAR CAVA LM          2
# APRUMAR POSTE RD LM                          2
# TURMA LV INST POSTE EST SUSP 2-3F  4P LV     2
# RETIRAR CHAVE FUSIVEL  LM                    2
# CONECTAR RAMAL LIGACAO 1F/2F LM              1
# INST CHAVE FUSIVEL RELIGADORA 4P LV          1
# INSTALAR PARA-RAIOS BT LM                    1
# RETIRAR CHAVE FUSIVEL 15KV 4P LV             1
# INSTALAR CHAVE FUSIVEL 15KV LM               1
# INSTALAR ESTRUTURA RELIGADOR RD LM           1
# RETIRAR ESTRUTURA RELIGADOR RD LM            1
# RETIRAR CHAVE FUSIVEL RELIGADORA 4P LV       1
# Name: count, dtype: int64
#
# Nomes das colunas após a filtragem:
# Index(['PEP&ORDEM&SERVIÇO', 'PI', 'TIPO', 'TIPO DE MEDIÇÃO',
#        'TIPO DE MEDIÇÃO.1', 'PEP IV NÍVEL', 'STATUS PEP',
#        'STATUS PEP\n(ALTERADO)', 'ORDEM/DIAGRAMA', 'STATUS ORDEM/DIAGRAMA',
#        'NOTA PROJ', 'DESCR. DA OBRA', 'CADERNO', 'ITEM', 'CÓD. SERVIÇO',
#        'CÓD. SERVIÇO&ITEM', 'DESCRIÇÃO DE SERVIÇO', 'UN.', 'PU', 'QUANT / KM',
#        'VALOR', 'QUANT / KM.1', 'VALOR.1', 'TIPO DE MEDIÇÃO.2',
#        'TIPO DE MEDIÇÃO.3', 'TÉCNICO OBRA', 'SUPERVISOR/SOLICITANTE',
#        'PERÍODO DE MEDIÇÃO', 'DATA DO SERVIÇO', 'DESLOCAMENTO\nDE',
#        'DESLOCAMENTO\nPARA', 'EQUIPE', 'ESTRUTURA',
#        'CONTROLE\n(DADOS ENGENHARIA)', 'SOLICITAÇÃO DE\nINTERVENÇÃO\n(SI)',
#        'OBS PARCEIRA', 'REGIONAL', 'MEDIÇÃO', 'Origem'],
#       dtype='object')
# Colunas excluídas com sucesso!
# Arquivo C:\Users\E1180062\Downloads\Análise de Orçamento\Dados_Combinados_MAR_PHB.xlsx lido com sucesso!
# Frequência dos serviços:
#  DESCRIÇÃO DE SERVIÇO
# INST COBERTURA PROVISORIA CONDUTOR 4P LV    102
# INST JUMPER OU PASSAGEM NEUTRO 4P LV         41
# REAPERTAR ESTRUTURA PRIMARIA 4P LV           38
# INSTALAR CHAVE FUSIVEL 4P LV                 32
# RETIRAR CHAVE FUSIVEL 4P LV                  31
#                                            ...
# SUBSTITUIR ISOLADOR PINO OU PINO 4P LV        1
# RETIRAR ESTR CRUZ SUSP DUP 4P LV              1
# SUBSTITUIR EMENDA CONDUTOR NU 4PLV            1
# RETIRAR CONDUTOR NU ALUMINIO > 1/0 LM         1
# INSTALAR ESTRUT PRI CRUZETA SIMPLES LM        1
# Name: count, Length: 82, dtype: int64
# Arquivo filtrado C:\Users\E1180062\Downloads\Análise de Orçamento\Dados_Combinados_MAR_PHB.xlsx:
#         PEP&ORDEM&SERVIÇO  PI  TIPO TIPO DE MEDIÇÃO TIPO DE MEDIÇÃO.1  \
# 26                    NaN NaN   NaN         Custeio           custeio
# 28                    NaN NaN   NaN         Custeio           custeio
# 42                    NaN NaN   NaN         Custeio           custeio
# 70                    NaN NaN   NaN         Custeio           Custeio
# 71                    NaN NaN   NaN         Custeio           Custeio
# ..                    ...  ..   ...             ...               ...
# 610  60007593545033000132 NaN   NaN         Custeio         MED ÚNICA
# 624  60007539275033000146 NaN   NaN         Custeio         MED ÚNICA
# 626  60007539275033000132 NaN   NaN         Custeio         MED ÚNICA
# 637  60007595615033000146 NaN   NaN         Custeio         MED ÚNICA
# 639  60007595615033000132 NaN   NaN         Custeio         MED ÚNICA
#
#     PEP IV NÍVEL  STATUS PEP STATUS PEP\n(ALTERADO)  ORDEM/DIAGRAMA  \
# 26           NaN         NaN                      /      6000749036
# 28           NaN         NaN                      /      6000749036
# 42           NaN         NaN                      /      6000749036
# 70           NaN         NaN                      /      6000723606
# 71           NaN         NaN                      /      6000723606
# ..           ...         ...                    ...             ...
# 610          NaN         NaN                      /      6000759354
# 624          NaN         NaN                      /      6000753927
# 626          NaN         NaN                      /      6000753927
# 637          NaN         NaN                      /      6000759561
# 639          NaN         NaN                      /      6000759561
#
#     STATUS ORDEM/DIAGRAMA  ...  DESLOCAMENTO\nDE         DESLOCAMENTO\nPARA  \
# 26                    NaN  ...          PARNAIBA  COND. CONVIVER DO LITORAL
# 28                    NaN  ...          PARNAIBA  COND. CONVIVER DO LITORAL
# 42                    NaN  ...          PARNAIBA  COND. CONVIVER DO LITORAL
# 70               LIB/ATEC  ...    MATIAS OLIMPIO                     BR 222
# 71               LIB/ATEC  ...    MATIAS OLIMPIO                     BR 222
# ..                    ...  ...               ...                        ...
# 610              LIB/ATEC  ...               NaN                        NaN
# 624              LIB/ATEC  ...               NaN                        NaN
# 626              LIB/ATEC  ...               NaN                        NaN
# 637              LIB/ATEC  ...               NaN                        NaN
# 639              LIB/ATEC  ...               NaN                        NaN
#
#        EQUIPE  ESTRUTURA  CONTROLE\n(DADOS ENGENHARIA)  \
# 26   TATPAB01        NaN                           NaN
# 28   TATPAB01        NaN                           NaN
# 42   TATPAB01        NaN                           NaN
# 70   LVPPAB01        NaN                           NaN
# 71   LVPPAB01        NaN                           NaN
# ..        ...        ...                           ...
# 610       NaN        NaN                           NaN
# 624       NaN        NaN                           NaN
# 626       NaN        NaN                           NaN
# 637       NaN        NaN                           NaN
# 639       NaN        NaN                           NaN
#
#      SOLICITAÇÃO DE\nINTERVENÇÃO\n(SI) OBS PARCEIRA REGIONAL  MEDIÇÃO  \
# 26                                 NaN          NaN       ok      NaN
# 28                                 NaN          NaN       ok      NaN
# 42                                 NaN          NaN       ok      NaN
# 70                              344602          NaN       OK      NaN
# 71                              344602          NaN       OK      NaN
# ..                                 ...          ...      ...      ...
# 610                          NDS 4-152          NaN       OK      NaN
# 624                             350714          NaN       OK      NaN
# 626                             350714          NaN       OK      NaN
# 637                          NDS 4-190          NaN       OK      NaN
# 639                          NDS 4-190          NaN       OK      NaN
#
#                                                 Origem
# 26   C:\Users\E1180062\Downloads\Análise de Orçamen...
# 28   C:\Users\E1180062\Downloads\Análise de Orçamen...
# 42   C:\Users\E1180062\Downloads\Análise de Orçamen...
# 70   C:\Users\E1180062\Downloads\Análise de Orçamen...
# 71   C:\Users\E1180062\Downloads\Análise de Orçamen...
# ..                                                 ...
# 610  C:\Users\E1180062\Downloads\Análise de Orçamen...
# 624  C:\Users\E1180062\Downloads\Análise de Orçamen...
# 626  C:\Users\E1180062\Downloads\Análise de Orçamen...
# 637  C:\Users\E1180062\Downloads\Análise de Orçamen...
# 639  C:\Users\E1180062\Downloads\Análise de Orçamen...
#
# [114 rows x 39 columns]
# Frequência dos serviços filtrados:
#  DESCRIÇÃO DE SERVIÇO
# INSTALAR CHAVE FUSIVEL 4P LV                32
# RETIRAR CHAVE FUSIVEL 4P LV                 31
# INSTALAR PARA-RAIOS 4P LV                    7
# RETIRAR PARA-RAIOS 4P LV                     6
# TURMA LV INST POSTE EST SUSP 2-3F  4P LV     6
# INST CHAVE FACA 4P LV                        5
# REAPERTAR E REGULAR CHAVE BY-PASS 4P LV      4
# DESCONEC E CONEC RAMAL CLIENTE 3F LM         3
# RETIRAR CHAVE FACA 4P LV                     3
# RETIRAR CHAVE FUSIVEL  LM                    3
# APRUMAR POSTE RD LM                          2
# INSTALAR CHAVE FUSIVEL 15KV LM               2
# RETIRAR POSTE 10 A 14M FECHAR CAVA LM        2
# RETIRAR POSTE 7 A 9M FECHAR CAVA LM          1
# RETIRAR ESTRUTURA RELIGADOR RD LM            1
# INSTALAR ESTRUTURA RELIGADOR RD LM           1
# INSTALAR PARA-RAIOS BT LM                    1
# DESCONECTAR RAMAL LIGACAO 1F/2F              1
# CONECTAR RAMAL LIGACAO 1F/2F LM              1
# RETIRAR CHAVE FUSIVEL 15KV 4P LV             1
# INST CHAVE FUSIVEL RELIGADORA 4P LV          1
# Name: count, dtype: int64
#
# Nomes das colunas após a filtragem:
# Index(['PEP&ORDEM&SERVIÇO', 'PI', 'TIPO', 'TIPO DE MEDIÇÃO',
#        'TIPO DE MEDIÇÃO.1', 'PEP IV NÍVEL', 'STATUS PEP',
#        'STATUS PEP\n(ALTERADO)', 'ORDEM/DIAGRAMA', 'STATUS ORDEM/DIAGRAMA',
#        'NOTA PROJ', 'DESCR. DA OBRA', 'CADERNO', 'ITEM', 'CÓD. SERVIÇO',
#        'CÓD. SERVIÇO&ITEM', 'DESCRIÇÃO DE SERVIÇO', 'UN.', 'PU', 'QUANT / KM',
#        'VALOR', 'QUANT / KM.1', 'VALOR.1', 'TIPO DE MEDIÇÃO.2',
#        'TIPO DE MEDIÇÃO.3', 'TÉCNICO OBRA', 'SUPERVISOR/SOLICITANTE',
#        'PERÍODO DE MEDIÇÃO', 'DATA DO SERVIÇO', 'DESLOCAMENTO\nDE',
#        'DESLOCAMENTO\nPARA', 'EQUIPE', 'ESTRUTURA',
#        'CONTROLE\n(DADOS ENGENHARIA)', 'SOLICITAÇÃO DE\nINTERVENÇÃO\n(SI)',
#        'OBS PARCEIRA', 'REGIONAL', 'MEDIÇÃO', 'Origem'],
#       dtype='object')
# Colunas excluídas com sucesso!
# Arquivo C:\Users\E1180062\Downloads\Análise de Orçamento\Dados_Combinados_ABR_PHB.xlsx lido com sucesso!
# Frequência dos serviços:
#  DESCRIÇÃO DE SERVIÇO
# INST COBERTURA PROVISORIA CONDUTOR 4P LV    102
# REAPERTAR ESTRUTURA PRIMARIA 4P LV           49
# INST JUMPER OU PASSAGEM NEUTRO 4P LV         42
# PODAR OU CORTAR ARVORE AREA URBANA LM        27
# AVISO ENTREGA DE CARTA P/ DESLIG S/ PROT     19
#                                            ...
# TENSIONAR COND ISOLADO BT 3#70(70) LM         1
# EMENDAR CONDUTOR NU 3P LV                     1
# SUBSTITUIR ISOLADOR PINO OU PINO 4P LV        1
# RETIRAR CHAVE FUSIVEL  LM                     1
# INSTALAR ESTRUTURA SECUNDARIA LM              1
# Name: count, Length: 109, dtype: int64
# Arquivo filtrado C:\Users\E1180062\Downloads\Análise de Orçamento\Dados_Combinados_ABR_PHB.xlsx:
#         PEP&ORDEM&SERVIÇO  PI  TIPO TIPO DE MEDIÇÃO TIPO DE MEDIÇÃO.1  \
# 5                     NaN NaN   NaN         Custeio           Custeio
# 6                     NaN NaN   NaN         Custeio           Custeio
# 16                    NaN NaN   NaN         Custeio           Custeio
# 17                    NaN NaN   NaN         Custeio           Custeio
# 60                    NaN NaN   NaN         Custeio           Custeio
# ..                    ...  ..   ...             ...               ...
# 613  60007702685033000159 NaN   NaN         Custeio         MED ÚNICA
# 627  60007705915033000146 NaN   NaN         Custeio         MED ÚNICA
# 629  60007705915033000132 NaN   NaN         Custeio         MED ÚNICA
# 634  60007705915033000146 NaN   NaN         Custeio         MED ÚNICA
# 637  60007705915033000132 NaN   NaN         Custeio         MED ÚNICA
#
#     PEP IV NÍVEL  STATUS PEP STATUS PEP\n(ALTERADO)  ORDEM/DIAGRAMA  \
# 5            NaN         NaN                      /      6000752928
# 6            NaN         NaN                      /      6000749036
# 16           NaN         NaN                      /      6000752316
# 17           NaN         NaN                      /      6000752316
# 60           NaN         NaN                      /      6000752928
# ..           ...         ...                    ...             ...
# 613          NaN         NaN                      /      6000770268
# 627          NaN         NaN                      /      6000770591
# 629          NaN         NaN                      /      6000770591
# 634          NaN         NaN                      /      6000770591
# 637          NaN         NaN                      /      6000770591
#
#     STATUS ORDEM/DIAGRAMA  ...   DESLOCAMENTO\nDE         DESLOCAMENTO\nPARA  \
# 5                     NaN  ...  CAJUEIRO DA PRAIA          PV CANTO COMPRIDO
# 6                     NaN  ...           PARNAIBA  COND. CONVIVER DO LITORAL
# 16                    NaN  ...           PARNAIBA     COND. JARDIM ATLÂNTICO
# 17                    NaN  ...           PARNAIBA     COND. JARDIM ATLÂNTICO
# 60                    NaN  ...  CAJUEIRO DA PRAIA          PV CANTO COMPRIDO
# ..                    ...  ...                ...                        ...
# 613              LIB/ATEC  ...                NaN                        NaN
# 627              LIB/ATEC  ...                NaN                        NaN
# 629              LIB/ATEC  ...                NaN                        NaN
# 634              LIB/ATEC  ...                NaN                        NaN
# 637              LIB/ATEC  ...                NaN                        NaN
#
#        EQUIPE  ESTRUTURA  CONTROLE\n(DADOS ENGENHARIA)  \
# 5    TATPAB01        NaN                           NaN
# 6    TATPAB01        NaN                           NaN
# 16   TATPAB01        NaN                           NaN
# 17   TATPAB01        NaN                           NaN
# 60   TATPAB01        NaN                           NaN
# ..        ...        ...                           ...
# 613       NaN        NaN                           NaN
# 627       NaN        NaN                           NaN
# 629       NaN        NaN                           NaN
# 634       NaN        NaN                           NaN
# 637       NaN        NaN                           NaN
#
#      SOLICITAÇÃO DE\nINTERVENÇÃO\n(SI) OBS PARCEIRA REGIONAL  MEDIÇÃO  \
# 5                               351393          NaN       ok      NaN
# 6                                  NaN          NaN       ok      NaN
# 16                                 NaN          NaN       ok      NaN
# 17                                 NaN          NaN       ok      NaN
# 60                              351393          NaN       ok      NaN
# ..                                 ...          ...      ...      ...
# 613                          SI 353825          NaN       OK      NaN
# 627                          SI 354107          NaN       OK      NaN
# 629                          SI 354107          NaN       OK      NaN
# 634                          SI 354107          NaN       OK      NaN
# 637                          SI 354107          NaN       OK      NaN
#
#                                                 Origem
# 5    C:\Users\E1180062\Downloads\Análise de Orçamen...
# 6    C:\Users\E1180062\Downloads\Análise de Orçamen...
# 16   C:\Users\E1180062\Downloads\Análise de Orçamen...
# 17   C:\Users\E1180062\Downloads\Análise de Orçamen...
# 60   C:\Users\E1180062\Downloads\Análise de Orçamen...
# ..                                                 ...
# 613  C:\Users\E1180062\Downloads\Análise de Orçamen...
# 627  C:\Users\E1180062\Downloads\Análise de Orçamen...
# 629  C:\Users\E1180062\Downloads\Análise de Orçamen...
# 634  C:\Users\E1180062\Downloads\Análise de Orçamen...
# 637  C:\Users\E1180062\Downloads\Análise de Orçamen...
#
# [105 rows x 39 columns]
# Frequência dos serviços filtrados:
#  DESCRIÇÃO DE SERVIÇO
# SUBSTITUIR CHAVE FUSIVEL 4P LV              13
# INSTALAR CHAVE FUSIVEL 4P LV                12
# RETIRAR CHAVE FUSIVEL 4P LV                 11
# RETIRAR PARA-RAIOS 4P LV                     9
# RETIRAR CHAVE FUSIVEL 4P LV                  8
# INSTALAR CHAVE FUSIVEL 4P LV                 8
# APRUMAR POSTE RD LM                          5
# INSTALAR PARA-RAIOS 4P LV                    5
# TURMA LV INST POSTE EST SUSP 2-3F  4P LV     4
# INST CHAVE FUSIVEL RELIGADORA 4P LV          2
# RETIRAR CHAVE FACA 4P LV                     2
# INSTALAR CHAVE FUSIVEL 15KV LM               2
# DESCONECTAR RAMAL LIGACAO 1F/2F              2
# INSTALAR PARA-RAIOS LM                       2
# RETIRAR PARA-RAIOS LM                        2
# RETIRAR PARA-RAIOS 4P LV                     2
# CONECTAR RAMAL LIGACAO 1F/2F LM              2
# APRUMAR POSTE RD LM                          1
# INST CHAVE BY-PASS 4P LV                     1
# INST CHAVE FACA 4P LV                        1
# REAPERTAR E REGULAR CHAVE BY-PASS 4P LV      1
# RETIRAR CHAVE FUSIVEL  LM                    1
# INSTALAR CHAVE FUSIVEL 15KV LM               1
# RETIRAR CHAVE FUSIVEL  LM                    1
# DESCONECTAR RAMAL LIGACAO 1F/2F              1
# CONECTAR RAMAL LIGACAO 1F/2F LM              1
# RETIRAR POSTE 10 A 14M FECHAR CAVA LM        1
# RETIRAR CHAVE FUSIVEL 15KV 4P LV             1
# INSTALAR PARA-RAIOS BT LM                    1
# RETIRAR TRAFO DIST POSTE LM                  1
# RETIRAR CHAVE FUSIVEL RELIGADORA 4P LV       1
# Name: count, dtype: int64
#
# Nomes das colunas após a filtragem:
# Index(['PEP&ORDEM&SERVIÇO', 'PI', 'TIPO', 'TIPO DE MEDIÇÃO',
#        'TIPO DE MEDIÇÃO.1', 'PEP IV NÍVEL', 'STATUS PEP',
#        'STATUS PEP\n(ALTERADO)', 'ORDEM/DIAGRAMA', 'STATUS ORDEM/DIAGRAMA',
#        'NOTA PROJ', 'DESCR. DA OBRA', 'CADERNO', 'ITEM', 'CÓD. SERVIÇO',
#        'CÓD. SERVIÇO&ITEM', 'DESCRIÇÃO DE SERVIÇO', 'UN.', 'PU', 'QUANT / KM',
#        'VALOR', 'QUANT / KM.1', 'VALOR.1', 'TIPO DE MEDIÇÃO.2',
#        'TIPO DE MEDIÇÃO.3', 'TÉCNICO OBRA', 'SUPERVISOR/SOLICITANTE',
#        'PERÍODO DE MEDIÇÃO', 'DATA DO SERVIÇO', 'DESLOCAMENTO\nDE',
#        'DESLOCAMENTO\nPARA', 'EQUIPE', 'ESTRUTURA',
#        'CONTROLE\n(DADOS ENGENHARIA)', 'SOLICITAÇÃO DE\nINTERVENÇÃO\n(SI)',
#        'OBS PARCEIRA', 'REGIONAL', 'MEDIÇÃO', 'Origem'],
#       dtype='object')
# Colunas excluídas com sucesso!
# Arquivo C:\Users\E1180062\Downloads\Análise de Orçamento\Dados_Combinados_MAI_PHB.xlsx lido com sucesso!
# Frequência dos serviços:
#  DESCRIÇÃO DE SERVIÇO
# INST COBERTURA PROVISORIA CONDUTOR 4P LV    89
# INST JUMPER OU PASSAGEM NEUTRO 4P LV        46
# REAPERTAR ESTRUTURA PRIMARIA 4P LV          42
# INST ISOLADOR PINO OU PINO FL 4P LV         28
# AVISO ENTREGA DE CARTA P/ DESLIG S/ PROT    28
#                                             ..
# INST ISOLADOR PINO OU PINO 3P LV             1
# SUBSTITUIR ISOLAD PINO OU PINO FL 4P LV      1
# TURMA LV INST POSTE 2 ESTRUT 2-3F 4P LV      1
# INST ESTR CRUZ SUSP SIM 4P LV                1
# SUBSTITUIR CONECTOR PRIMARIA 4P LV           1
# Name: count, Length: 68, dtype: int64
# Arquivo filtrado C:\Users\E1180062\Downloads\Análise de Orçamento\Dados_Combinados_MAI_PHB.xlsx:
#         PEP&ORDEM&SERVIÇO  PI  TIPO TIPO DE MEDIÇÃO TIPO DE MEDIÇÃO.1  \
# 1                     NaN NaN   NaN         Custeio           Custeio
# 12   60007533745033000062 NaN   NaN         Custeio           Custeio
# 23   60007795705033000132 NaN   NaN         Custeio           Custeio
# 24   60007795705033000146 NaN   NaN         Custeio           Custeio
# 30   60007708165033000132 NaN   NaN         Custeio           Custeio
# ..                    ...  ..   ...             ...               ...
# 514  60007855535033000132 NaN   NaN         Custeio         MED ÚNICA
# 516  60007855535033000159 NaN   NaN         Custeio         MED ÚNICA
# 520  60007855535033000146 NaN   NaN         Custeio         MED ÚNICA
# 522  60007855535033000132 NaN   NaN         Custeio         MED ÚNICA
# 528  60007760785033000132 NaN   NaN         Custeio         MED ÚNICA
#
#     PEP IV NÍVEL  STATUS PEP STATUS PEP\n(ALTERADO)  ORDEM/DIAGRAMA  \
# 1            NaN         NaN                      /      6000779574
# 12           NaN         NaN                      /      6000753374
# 23           NaN         NaN                      /      6000779570
# 24           NaN         NaN                      /      6000779570
# 30           NaN         NaN                      /      6000770816
# ..           ...         ...                    ...             ...
# 514          NaN         NaN                      /      6000785553
# 516          NaN         NaN                      /      6000785553
# 520          NaN         NaN                      /      6000785553
# 522          NaN         NaN                      /      6000785553
# 528          NaN         NaN                      /      6000776078
#
#     STATUS ORDEM/DIAGRAMA  ...  DESLOCAMENTO\nPARA    EQUIPE ESTRUTURA  \
# 1                     NaN  ...      MATIAS OLIMPIO  LVPPAB01       NaN
# 12               LIB/ATEC  ...  AV ANTONIO JOAQUIM  LVPPAB01       NaN
# 23               LIB/ATEC  ...        ALTO BONNITO  LVPPAB01       NaN
# 24               LIB/ATEC  ...        ALTO BONNITO  LVPPAB01       NaN
# 30                    NaN  ...            PARNAIBA  LVLPAB01       NaN
# ..                    ...  ...                 ...       ...       ...
# 514              LIB/ATEC  ...                 NaN       NaN       NaN
# 516              LIB/ATEC  ...                 NaN       NaN       NaN
# 520              LIB/ATEC  ...                 NaN       NaN       NaN
# 522              LIB/ATEC  ...                 NaN       NaN       NaN
# 528              LIB/ATEC  ...                 NaN       NaN       NaN
#
#      CONTROLE\n(DADOS ENGENHARIA)  SOLICITAÇÃO DE\nINTERVENÇÃO\n(SI)  \
# 1                             NaN                                NaN
# 12                            NaN                             353801
# 23                            NaN                             354717
# 24                            NaN                             354717
# 30                            NaN                                NaN
# ..                            ...                                ...
# 514                           NaN                          SI 355777
# 516                           NaN                          SI 355777
# 520                           NaN                          SI 355777
# 522                           NaN                          SI 355777
# 528                           NaN                          NDS 6-322
#
#      NOTA\nRECLAMAÇÃO\n(NR) OBS PARCEIRA                        REGIONAL  \
# 1                       NaN          NaN           NOK - PAGAR POR OBRAS
# 12                      NaN          NaN                              OK
# 23                      NaN          NaN                              OK
# 24                      NaN          NaN                              OK
# 30                      NaN          NaN  NOK - SERÁ COBRADO VIA PROJETO
# ..                      ...          ...                             ...
# 514                     NaN          NaN                              OK
# 516                     NaN          NaN      NO - SERVIÇO NÃO EXECUTADO
# 520                     NaN          NaN                              OK
# 522                     NaN          NaN                              OK
# 528                     NaN          NaN                              OK
#
#      MEDIÇÃO                                             Origem
# 1        NaN  C:\Users\E1180062\Downloads\Análise de Orçamen...
# 12       NaN  C:\Users\E1180062\Downloads\Análise de Orçamen...
# 23       NaN  C:\Users\E1180062\Downloads\Análise de Orçamen...
# 24       NaN  C:\Users\E1180062\Downloads\Análise de Orçamen...
# 30       NaN  C:\Users\E1180062\Downloads\Análise de Orçamen...
# ..       ...                                                ...
# 514      NaN  C:\Users\E1180062\Downloads\Análise de Orçamen...
# 516      NaN  C:\Users\E1180062\Downloads\Análise de Orçamen...
# 520      NaN  C:\Users\E1180062\Downloads\Análise de Orçamen...
# 522      NaN  C:\Users\E1180062\Downloads\Análise de Orçamen...
# 528      NaN  C:\Users\E1180062\Downloads\Análise de Orçamen...
#
# [107 rows x 41 columns]
# Frequência dos serviços filtrados:
#  DESCRIÇÃO DE SERVIÇO
# RETIRAR CHAVE FUSIVEL 4P LV                 25
# INSTALAR CHAVE FUSIVEL 4P LV                22
# RETIRAR CHAVE FUSIVEL 4P LV                 13
# INSTALAR CHAVE FUSIVEL 4P LV                11
# RETIRAR PARA-RAIOS 4P LV                    10
# INSTALAR PARA-RAIOS 4P LV                    7
# RETIRAR PARA-RAIOS 4P LV                     4
# INST CHAVE FUSIVEL RELIGADORA 4P LV          3
# INSTALAR PARA-RAIOS 4P LV                    2
# RETIRAR CHAVE FUSIVEL RELIGADORA 4P LV       2
# REAPERTAR E REGULAR CHAVE BY-PASS 4P LV      2
# RETIRAR TRAFO DIST POSTE LM                  1
# SUBSTITUIR CHAVE FUSIVEL 4P LV               1
# INSTALAR CHAVE FUSIVEL 3P LV                 1
# INST CHAVE FACA 4P LV                        1
# RETIRAR CHAVE FUSIVEL RELIGADORA 4P LV       1
# TURMA LV INST POSTE 2 ESTRUT 2-3F 4P LV      1
# Name: count, dtype: int64
#
# Nomes das colunas após a filtragem:
# Index(['PEP&ORDEM&SERVIÇO', 'PI', 'TIPO', 'TIPO DE MEDIÇÃO',
#        'TIPO DE MEDIÇÃO.1', 'PEP IV NÍVEL', 'STATUS PEP',
#        'STATUS PEP\n(ALTERADO)', 'ORDEM/DIAGRAMA', 'STATUS ORDEM/DIAGRAMA',
#        'NOTA PROJ', 'DESCR. DA OBRA', 'CADERNO', 'ITEM', 'CÓD. SERVIÇO',
#        'CÓD. SERVIÇO&ITEM', 'DESCRIÇÃO DE SERVIÇO', 'UN.', 'PU', 'QUANT / KM',
#        'VALOR', 'QUANT / KM.1', 'VALOR.1', 'TIPO DE MEDIÇÃO.2',
#        'TIPO DE MEDIÇÃO.3', 'TÉCNICO OBRA', 'SUPERVISOR/SOLICITANTE',
#        'PERÍODO DE MEDIÇÃO', 'DATA DO SERVIÇO', 'MUNICÍPIO',
#        'DESLOCAMENTO\nDE', 'DESLOCAMENTO\nPARA', 'EQUIPE', 'ESTRUTURA',
#        'CONTROLE\n(DADOS ENGENHARIA)', 'SOLICITAÇÃO DE\nINTERVENÇÃO\n(SI)',
#        'NOTA\nRECLAMAÇÃO\n(NR)', 'OBS PARCEIRA', 'REGIONAL', 'MEDIÇÃO',
#        'Origem'],
#       dtype='object')
# Colunas excluídas com sucesso!
# Dados unificados com sucesso!

# %%
# Salvando o resultado em uma nova planilha
novo_output_file = r'C:\Users\E1180062\Downloads\Análise de Orçamento\Dados Unificados Regionais\Dados_Unificados_PHB.xlsx'
try:
    df_unificado.to_excel(novo_output_file, index=False, sheet_name="PHB")
    print(f"\nArquivo salvo com sucesso em: {novo_output_file}")
except Exception as e:
    print(f"Erro ao salvar o arquivo: {e}")
# Out:
# Arquivo salvo com sucesso em: C:\Users\E1180062\Downloads\Análise de Orçamento\Dados Unificados Regionais\Dados_Unificados_PHB.xlsx
