# %%
import pandas as pd

# %%
# Lista de arquivos Excel a serem processados
arquivos_entrada = [
    r'C:\Users\E1180062\Downloads\Análise de Orçamento\Dados_Combinados_JAN_MET.xlsx',
    r'C:\Users\E1180062\Downloads\Análise de Orçamento\Dados_Combinados_FEV_MET.xlsx',
    r'C:\Users\E1180062\Downloads\Análise de Orçamento\Dados_Combinados_MAR_MET.xlsx',
    r'C:\Users\E1180062\Downloads\Análise de Orçamento\Dados_Combinados_ABR_MET.xlsx',
    r'C:\Users\E1180062\Downloads\Análise de Orçamento\Dados_Combinados_MAI_MET.xlsx',
    r'C:\Users\E1180062\Downloads\Análise de Orçamento\Dados_Combinados_JUN_MET.xlsx'
]

# %%
def processar_arquivo(arquivo_entrada):
    try:
        # Leitura do arquivo Excel
        df = pd.read_excel(arquivo_entrada)
        print(f"Arquivo {arquivo_entrada} lido com sucesso!")
        
        # Adiciona coluna com o nome do arquivo
        df['Origem'] = arquivo_entrada
        
        # Verificação da leitura e contagem de frequência
        try:
            frequencia_servico = df['DESCRIÇÃO DE SERVIÇO'].value_counts()
            print("Frequência dos serviços:\n", frequencia_servico)
        except KeyError as e:
            print(f"Erro: a coluna {e} não foi encontrada no DataFrame.")
        
        # Filtragem das linhas com palavras-chave
        criterios = ['chave fusivel','chave faca','chave by-pass', 'para-raios', 'poste', 'ramal', 'cabo', 'religador']
        try:
            mascara1 = df['DESCRIÇÃO DE SERVIÇO'].str.contains('|'.join(criterios), case=False, na=False)
            df_filtrado = df[mascara1]
            print(f"Arquivo filtrado {arquivo_entrada}:")
            display(df_filtrado)
        except KeyError as e:
            print(f"Erro: a coluna {e} não foi encontrada no DataFrame.")
        
        # Contagem de frequência dos serviços filtrados
        if not df_filtrado.empty:
            frequencia_servico_filtrado = df_filtrado['DESCRIÇÃO DE SERVIÇO'].value_counts()
            print("Frequência dos serviços filtrados:\n", frequencia_servico_filtrado)
        else:
            print("Nenhum dado filtrado encontrado.")
        
        # Exibição dos nomes das colunas após a filtragem 
        if not df_filtrado.empty:
            print("\nNomes das colunas após a filtragem:")
            print(df_filtrado.columns)
        
        # Exclusão de colunas desnecessárias
        excluir_colunas = ['PEP&ORDEM&SERVIÇO','PI','EQUIPE','TIPO','TIPO DE MEDIÇÃO','Tipo de Medição','PEP IV NÍVEL','STATUS PEP', 'UN.','PU', 'OBS EQTL','Unnamed: 44', 'TIPO DE MEDIÇÃO.1',
                          'STATUS PEP\n(ALTERADO)','ORDEM/DIAGRAMA','STATUS ORDEM/DIAGRAMA','NOTA PROJ', 'Unnamed: 41', 'Unnamed: 45', 'TIPO DE MEDIÇÃO.1',
                          'ÁREA                                     DISTRIBUIDORA','CADERNO','ITEM','CÓD. SERVIÇO','CÓD. SERVIÇO&ITEM', 'TIPO DE MEDIÇÃO.2',
                          'QUANT / KM','QUANT / KM.1','TIPO DE MEDIÇÃO','PERÍODO DE MEDIÇÃO','TÉCNICO OBRA','NDS ', 'Unnamed: 42', 'Área Resp (DISTRIBUIDORA)',
                          'SUPERVISOR/SOLICITANTE','MUNICÍPIO','MUNICIPIO','DESLOCAMENTO\nDE','DESLOCAMENTO\nPARA', 'Unnamed: 43', 'Unnamed: 23', 'CONTROLE\n(DADOS ENGENHARIA)'
                          'EQUIPE','ESTRUTURA','CONTROLE\n(dados Engenharia)','NOTA\nRECLAMAÇÃO\n(NR)', 'NOTA\nRECLAMAÇÃO / OCORRÊNCIA\n(NR / OC)',
                          'PEDIDO','OBS PARCEIRA','REGIONAL','MEDIÇÃO','OBRA ','OBRA','TÉCNICO RESPONSÁVEL','Área Resp\n(DISTRIBUIDORA)','TIPO DE MEDIÇÃO.3']
        try:
            df_final = df_filtrado.drop(columns=excluir_colunas, errors='ignore')
            print("Colunas excluídas com sucesso!")
        except Exception as e:
            print(f"Erro ao excluir colunas: {e}")
        
        return df_final
    except Exception as e:
        print(f"Erro ao processar o arquivo {arquivo_entrada}: {e}")
        return pd.DataFrame()

# %%
# Lista para armazenar DataFrames filtrados
todos_dados_filtrados = []

for arquivo in arquivos_entrada:
    df_processado = processar_arquivo(arquivo)
    if not df_processado.empty:
        todos_dados_filtrados.append(df_processado)

# Unificação dos DataFrames filtrados
if todos_dados_filtrados:
    df_unificado = pd.concat(todos_dados_filtrados, ignore_index=True)
    print("Dados unificados com sucesso!")
else:
    df_unificado = pd.DataFrame()
# Out:
# Arquivo C:\Users\E1180062\Downloads\Análise de Orçamento\Dados_Combinados_JAN_MET.xlsx lido com sucesso!
# Frequência dos serviços:
#  DESCRIÇÃO DE SERVIÇO
# INST COBERTURA PROVISORIA CONDUTOR 4P LV    166
# RETIRAR CHAVE FUSIVEL 4P LV                  90
# INSTALAR CHAVE FUSIVEL 4P LV                 89
# REAPERTAR ESTRUTURA PRIMARIA 4P LV           87
# AVISO ENTREGA DE CARTA P/ DESLIG S/ PROT     84
#                                            ...
# INSTALAR CONDUTOR NU ALUMINIO = 1/0 LM        1
# INSTALAR PLACA NUMERO COMPONENTE              1
# INSTALAR RAMAL CABO MULTIP ATE 16MM² LM       1
# RETIRAR ESTRUT PRIM 3F SEM CRUZ PASSANTE      1
# INSTALAR ESPACADOR LOSANGULAR RDC 4P LV       1
# Name: count, Length: 106, dtype: int64
# Arquivo filtrado C:\Users\E1180062\Downloads\Análise de Orçamento\Dados_Combinados_JAN_MET.xlsx:
#                                  PEP&ORDEM&SERVIÇO   PI TIPO TIPO DE MEDIÇÃO  \
# 4                                              NaN  NaN  NaN         Custeio
# 5                                              NaN  NaN  NaN         Custeio
# 11                                             NaN  NaN  NaN         Custeio
# 12                                             NaN  NaN  NaN         Custeio
# 13                                             NaN  NaN  NaN         Custeio
# ...                                            ...  ...  ...             ...
# 1814  PM-D23.30.7013.TER.LLD0160007248245033000146  NaN  NaN         Custeio
# 1816  PM-D23.30.7013.TER.LLD0160007248245033000062  NaN  NaN         Custeio
# 1820  PM-D23.30.7013.TER.LLD0160007248245033000132  NaN  NaN         Custeio
# 1822  PM-D23.30.7013.TER.LLD0160007248245033000159  NaN  NaN         Custeio
# 1824  PM-D23.30.7013.TER.LLD0160006338405033000131  NaN  NaN         Custeio
#
#      TIPO DE MEDIÇÃO.1              PEP IV NÍVEL  STATUS PEP  \
# 4            MED ÚNICA  PM-D22.30.7013.TER.LLD01         NaN
# 5            MED ÚNICA  PM-D21.30.0414.TER.LPD01         NaN
# 11           MED ÚNICA  PM-D22.30.7013.TER.LLD01         NaN
# 12           MED ÚNICA  PM-D22.30.7013.TER.LLD01         NaN
# 13           MED ÚNICA                       NaN         NaN
# ...                ...                       ...         ...
# 1814         MED ÚNICA  PM-D23.30.7013.TER.LLD01         NaN
# 1816         MED ÚNICA  PM-D23.30.7013.TER.LLD01         NaN
# 1820         MED ÚNICA  PM-D23.30.7013.TER.LLD01         NaN
# 1822         MED ÚNICA  PM-D23.30.7013.TER.LLD01         NaN
# 1824         MED ÚNICA  PM-D23.30.7013.TER.LLD01         NaN
#
#      STATUS PEP\n(ALTERADO)  ORDEM/DIAGRAMA STATUS ORDEM/DIAGRAMA  ...  \
# 4                       NaN    6.000700e+09                   NaN  ...
# 5                         /    6.000700e+09                   NaN  ...
# 11                      NaN    6.000700e+09                   NaN  ...
# 12                      NaN    6.000700e+09                   NaN  ...
# 13                      NaN    6.000695e+09                   NaN  ...
# ...                     ...             ...                   ...  ...
# 1814                      /    6.000725e+09                   NaN  ...
# 1816                      /    6.000725e+09                   NaN  ...
# 1820                      /    6.000725e+09                   NaN  ...
# 1822                      /    6.000725e+09                   NaN  ...
# 1824                      /    6.000634e+09                   NaN  ...
#
#       DESLOCAMENTO\nDE DESLOCAMENTO\nPARA    EQUIPE    ESTRUTURA  \
# 4             TERESINA           TERESINA  LVLTHE01   LINHA VIVA
# 5             TERESINA           TERESINA  LVLTHE01   LINHA VIVA
# 11            TERESINA           TERESINA  MANEQP01  LINHA MORTA
# 12            TERESINA           TERESINA  MANEQP01  LINHA MORTA
# 13            TERESINA           TERESINA  MANEQP01  LINHA MORTA
# ...                ...                ...       ...          ...
# 1814               NaN                NaN       NaN          NaN
# 1816               NaN                NaN       NaN          NaN
# 1820               NaN                NaN       NaN          NaN
# 1822               NaN                NaN       NaN          NaN
# 1824               NaN                NaN       NaN          NaN
#
#       SOLICITAÇÃO DE\nINTERVENÇÃO\n(SI)  NOTA\nRECLAMAÇÃO\n(NR) OBS PARCEIRA  \
# 4                                   NaN                     NaN          NaN
# 5                                   NaN                     NaN          NaN
# 11                                  NaN                     NaN          NaN
# 12                                  NaN                     NaN          NaN
# 13                                  NaN                     NaN          NaN
# ...                                 ...                     ...          ...
# 1814                                NaN                     NaN          NaN
# 1816                                NaN                     NaN          NaN
# 1820                                NaN                     NaN          NaN
# 1822                                NaN                     NaN          NaN
# 1824                                NaN                     NaN          NaN
#
#       REGIONAL  MEDIÇÃO                                             Origem
# 4          NaN      NaN  C:\Users\E1180062\Downloads\Análise de Orçamen...
# 5          NaN      NaN  C:\Users\E1180062\Downloads\Análise de Orçamen...
# 11         NaN      NaN  C:\Users\E1180062\Downloads\Análise de Orçamen...
# 12         NaN      NaN  C:\Users\E1180062\Downloads\Análise de Orçamen...
# 13         NaN      NaN  C:\Users\E1180062\Downloads\Análise de Orçamen...
# ...        ...      ...                                                ...
# 1814  VALIDADO      NaN  C:\Users\E1180062\Downloads\Análise de Orçamen...
# 1816  VALIDADO      NaN  C:\Users\E1180062\Downloads\Análise de Orçamen...
# 1820  VALIDADO      NaN  C:\Users\E1180062\Downloads\Análise de Orçamen...
# 1822  VALIDADO      NaN  C:\Users\E1180062\Downloads\Análise de Orçamen...
# 1824  VALIDADO      NaN  C:\Users\E1180062\Downloads\Análise de Orçamen...
#
# [483 rows x 40 columns]
# Frequência dos serviços filtrados:
#  DESCRIÇÃO DE SERVIÇO
# RETIRAR CHAVE FUSIVEL 4P LV                 90
# INSTALAR CHAVE FUSIVEL 4P LV                89
# INST CHAVE BY-PASS 4P LV                    64
# RETIRAR PARA-RAIOS 4P LV                    49
# INSTALAR PARA-RAIOS 4P LV                   47
# INSTALAR PARA-RAIOS BT LM                   17
# INSTALAR TRAFO DIST POSTE LM                17
# INSTALAR PARA-RAIOS LM                      16
# RETIRAR TRAFO DIST POSTE LM                 16
# INSTALAR MANILHA FUNDAÇÃO DE POSTE LM       13
# RETIRAR POSTE 7 A 9M FECHAR CAVA LM         10
# INSTALAR POSTE 7 A 9M LM                    10
# RETIRAR POSTE 10 A 14M FECHAR CAVA LM        8
# INSTALAR POSTE 10 A 14M LM                   7
# RETIRAR CHAVE FACA 4P LV                     6
# APRUMAR POSTE RD LM                          5
# INST CHAVE FACA 4P LV                        5
# DESCONECTAR RAMAL LIGACAO 1F/2F              4
# CONECTAR RAMAL LIGACAO 1F/2F LM              4
# TENSIONAR CABO MENSAG RDC4P LV               1
# APRUMAR POSTE RD LM                          1
# INSTALAR RAMAL CABO MULTIP ATE 16MM² LM      1
# RETIRAR PARA-RAIOS LM                        1
# INSTALAR CHAVE FUSIVEL 15KV LM               1
# RETIRAR CHAVE BY-PASS 4P LV                  1
# Name: count, dtype: int64
#
# Nomes das colunas após a filtragem:
# Index(['PEP&ORDEM&SERVIÇO', 'PI', 'TIPO', 'TIPO DE MEDIÇÃO',
#        'TIPO DE MEDIÇÃO.1', 'PEP IV NÍVEL', 'STATUS PEP',
#        'STATUS PEP\n(ALTERADO)', 'ORDEM/DIAGRAMA', 'STATUS ORDEM/DIAGRAMA',
#        'NOTA PROJ', 'DESCR. DA OBRA', 'CADERNO', 'ITEM', 'CÓD. SERVIÇO',
#        'CÓD. SERVIÇO&ITEM', 'DESCRIÇÃO DE SERVIÇO', 'UN.', 'PU', 'QUANT / KM',
#        'VALOR', 'QUANT / KM.1', 'VALOR.1', 'TIPO DE MEDIÇÃO.2',
#        'TIPO DE MEDIÇÃO.3', 'TÉCNICO OBRA', 'SUPERVISOR/SOLICITANTE',
#        'PERÍODO DE MEDIÇÃO', 'DATA DO SERVIÇO', 'MUNICÍPIO',
#        'DESLOCAMENTO\nDE', 'DESLOCAMENTO\nPARA', 'EQUIPE', 'ESTRUTURA',
#        'SOLICITAÇÃO DE\nINTERVENÇÃO\n(SI)', 'NOTA\nRECLAMAÇÃO\n(NR)',
#        'OBS PARCEIRA', 'REGIONAL', 'MEDIÇÃO', 'Origem'],
#       dtype='object')
# Colunas excluídas com sucesso!
# Arquivo C:\Users\E1180062\Downloads\Análise de Orçamento\Dados_Combinados_FEV_MET.xlsx lido com sucesso!
# Frequência dos serviços:
#  DESCRIÇÃO DE SERVIÇO
# INST COBERTURA PROVISORIA CONDUTOR 4P LV    176
# AVISO ENTREGA DE CARTA P/ DESLIG S/ PROT     98
# PODAR OU CORTAR ARVORE AREA URBANA LM        88
# AVISO ENTREGA DE CARTA P/ DESLIG C/ PROT     75
# SUBSTITUIR CHAVE FUSIVEL 4P LV               74
#                                            ...
# INSTALAR CONDUTOR ISOLADO BT 3#70(70) LM      1
# RETIRAR COND ISOLADO AL BT 3#70(70) LM        1
# INST CONDUTOR ISOLADO BT 1#35(35) LM          1
# HASTE ADICIONAL ATERRAMENTO LM                1
# RETIRAR CELULA CAPACITOR 4P LV                1
# Name: count, Length: 120, dtype: int64
# Arquivo filtrado C:\Users\E1180062\Downloads\Análise de Orçamento\Dados_Combinados_FEV_MET.xlsx:
#                                  PEP&ORDEM&SERVIÇO   PI TIPO TIPO DE MEDIÇÃO  \
# 3                                              NaN  NaN  NaN         Custeio
# 8                                              NaN  NaN  NaN         Custeio
# 15                                             NaN  NaN  NaN         Custeio
# 17                                             NaN  NaN  NaN         Custeio
# 26                                             NaN  NaN  NaN         Custeio
# ...                                            ...  ...  ...             ...
# 1593  PM-D23.30.7013.TER.LLD0160007191775033000131  NaN  NaN         Custeio
# 1596  PM-D23.30.7013.TER.LLD0160007191775033000169  NaN  NaN         Custeio
# 1598  PM-D23.30.7013.TER.LLD0160007191775033000062  NaN  NaN         Custeio
# 1601  PM-D23.30.7013.TER.LLD0160007191775033000132  NaN  NaN         Custeio
# 1602  PM-D23.30.7013.TER.LLD0160007191775033000159  NaN  NaN         Custeio
#
#      TIPO DE MEDIÇÃO.1              PEP IV NÍVEL  STATUS PEP  \
# 3            MED ÚNICA  PM-D22.30.7013.TER.LLD01         NaN
# 8            MED ÚNICA                       NaN         NaN
# 15           MED ÚNICA  PM-D22.30.7013.TER.LLD01         NaN
# 17           MED ÚNICA  PM-D22.30.7013.TER.LLD01         NaN
# 26           MED ÚNICA  PM-D22.30.7013.TER.LLD01         NaN
# ...                ...                       ...         ...
# 1593         MED ÚNICA  PM-D23.30.7013.TER.LLD01         NaN
# 1596         MED ÚNICA  PM-D23.30.7013.TER.LLD01         NaN
# 1598         MED ÚNICA  PM-D23.30.7013.TER.LLD01         NaN
# 1601         MED ÚNICA  PM-D23.30.7013.TER.LLD01         NaN
# 1602         MED ÚNICA  PM-D23.30.7013.TER.LLD01         NaN
#
#      STATUS PEP\n(ALTERADO)  ORDEM/DIAGRAMA STATUS ORDEM/DIAGRAMA  ...  \
# 3                       NaN      6000674621                   NaN  ...
# 8                       NaN      6000624427                   NaN  ...
# 15                      NaN      6000674510                   NaN  ...
# 17                      NaN      6000675281                   NaN  ...
# 26                      NaN      6000694814                   NaN  ...
# ...                     ...             ...                   ...  ...
# 1593                      /      6000719177                   NaN  ...
# 1596                      /      6000719177                   NaN  ...
# 1598                      /      6000719177                   NaN  ...
# 1601                      /      6000719177                   NaN  ...
# 1602                      /      6000719177                   NaN  ...
#
#       DESLOCAMENTO\nDE DESLOCAMENTO\nPARA    EQUIPE    ESTRUTURA  \
# 3             TERESINA           TERESINA  LVLTHE01   LINHA VIVA
# 8             TERESINA           TERESINA  MANTHE01  LINHA MORTA
# 15            TERESINA           TERESINA  LVPTHE01   LINHA VIVA
# 17            TERESINA           TERESINA  LVPTHE01   LINHA VIVA
# 26               ALTOS              ALTOS  LVPTHE02   LINHA VIVA
# ...                ...                ...       ...          ...
# 1593               NaN                NaN       NaN          NaN
# 1596               NaN                NaN       NaN          NaN
# 1598               NaN                NaN       NaN          NaN
# 1601               NaN                NaN       NaN          NaN
# 1602               NaN                NaN       NaN          NaN
#
#       SOLICITAÇÃO DE\nINTERVENÇÃO\n(SI)  NOTA\nRECLAMAÇÃO\n(NR) OBS PARCEIRA  \
# 3                              344411.0                     NaN   REAJUSTADO
# 8                                   NaN                     NaN          NaN
# 15                             344415.0                     NaN   REAJUSTADO
# 17                             344425.0                     NaN   REAJUSTADO
# 26                             344498.0                     NaN          NaN
# ...                                 ...                     ...          ...
# 1593                                NaN                     NaN          NaN
# 1596                                NaN                     NaN          NaN
# 1598                                NaN                     NaN          NaN
# 1601                                NaN                     NaN          NaN
# 1602                                NaN                     NaN          NaN
#
#                                                REGIONAL  MEDIÇÃO  \
# 3     NÃO VALIDADO, SUBSTITUIR SERVIÇO COD 503300016...      NaN
# 8                                                   NaN      NaN
# 15    NÃO VALIDADO, SUBSTITUIR SERVIÇO COD 503300016...      NaN
# 17    NÃO VALIDADO, SUBSTITUIR SERVIÇO COD 503300016...      NaN
# 26                                                  NaN      NaN
# ...                                                 ...      ...
# 1593                                                NaN      NaN
# 1596      colocar o serviço de substituir chave fusivel      NaN
# 1598                                                NaN      NaN
# 1601          incluso no serviço de substituir isolador      NaN
# 1602                                                NaN      NaN
#
#                                                  Origem
# 3     C:\Users\E1180062\Downloads\Análise de Orçamen...
# 8     C:\Users\E1180062\Downloads\Análise de Orçamen...
# 15    C:\Users\E1180062\Downloads\Análise de Orçamen...
# 17    C:\Users\E1180062\Downloads\Análise de Orçamen...
# 26    C:\Users\E1180062\Downloads\Análise de Orçamen...
# ...                                                 ...
# 1593  C:\Users\E1180062\Downloads\Análise de Orçamen...
# 1596  C:\Users\E1180062\Downloads\Análise de Orçamen...
# 1598  C:\Users\E1180062\Downloads\Análise de Orçamen...
# 1601  C:\Users\E1180062\Downloads\Análise de Orçamen...
# 1602  C:\Users\E1180062\Downloads\Análise de Orçamen...
#
# [385 rows x 40 columns]
# Frequência dos serviços filtrados:
#  DESCRIÇÃO DE SERVIÇO
# SUBSTITUIR CHAVE FUSIVEL 4P LV              74
# INST CHAVE BY-PASS 4P LV                    48
# RETIRAR PARA-RAIOS 4P LV                    36
# INSTALAR PARA-RAIOS 4P LV                   34
# INSTALAR PARA-RAIOS BT LM                   23
# RETIRAR CHAVE FUSIVEL 4P LV                 21
# INSTALAR PARA-RAIOS LM                      19
# INSTALAR TRAFO DIST POSTE LM                19
# RETIRAR TRAFO DIST POSTE LM                 18
# INSTALAR MANILHA FUNDAÇÃO DE POSTE LM       10
# RETIRAR POSTE 7 A 9M FECHAR CAVA LM          9
# DESCONECTAR RAMAL LIGACAO 1F/2F              8
# CONECTAR RAMAL LIGACAO 1F/2F LM              8
# INSTALAR POSTE 7 A 9M LM                     8
# RETIRAR CHAVE FACA 4P LV                     6
# INST CHAVE FACA 4P LV                        6
# INSTALAR CHAVE FUSIVEL 4P LV                 5
# APRUMAR POSTE RD LM                          4
# INST CHAVE FUSIVEL RELIGADORA 4P LV          4
# RETIRAR CHAVE FUSIVEL RELIGADORA 4P LV       4
# INSTALAR POSTE 10 A 14M LM                   3
# TENSIONAR CABO MENSAG RDC4P LV               3
# RETIRAR POSTE 10 A 14M FECHAR CAVA LM        2
# INSTALAR CHAVE FUSIVEL 15KV LM               2
# SUBSTITUIR CHAVE FUSIVEL LM                  2
# RETIRAR CHAVE FUSIVEL  LM                    2
# INSTALAR PARA-RAIOS BT LM                    1
# RETIRAR CHAVE FUSIVEL  LM                    1
# APRUMAR POSTE RD LM                          1
# INSTALAR CHAVE FUSIVEL 15KV LM               1
# RETIRAR POSTE 10 A 14M FECHAR CAVA LM        1
# INSTALAR MANILHA FUNDAÇÃO DE POSTE LM        1
# INSTALAR PARA-RAIOS LM                       1
# Name: count, dtype: int64
#
# Nomes das colunas após a filtragem:
# Index(['PEP&ORDEM&SERVIÇO', 'PI', 'TIPO', 'TIPO DE MEDIÇÃO',
#        'TIPO DE MEDIÇÃO.1', 'PEP IV NÍVEL', 'STATUS PEP',
#        'STATUS PEP\n(ALTERADO)', 'ORDEM/DIAGRAMA', 'STATUS ORDEM/DIAGRAMA',
#        'NOTA PROJ', 'DESCR. DA OBRA', 'CADERNO', 'ITEM', 'CÓD. SERVIÇO',
#        'CÓD. SERVIÇO&ITEM', 'DESCRIÇÃO DE SERVIÇO', 'UN.', 'PU', 'QUANT / KM',
#        'VALOR', 'QUANT / KM.1', 'VALOR.1', 'TIPO DE MEDIÇÃO.2',
#        'TIPO DE MEDIÇÃO.3', 'TÉCNICO OBRA', 'SUPERVISOR/SOLICITANTE',
#        'PERÍODO DE MEDIÇÃO', 'DATA DO SERVIÇO', 'MUNICÍPIO',
#        'DESLOCAMENTO\nDE', 'DESLOCAMENTO\nPARA', 'EQUIPE', 'ESTRUTURA',
#        'SOLICITAÇÃO DE\nINTERVENÇÃO\n(SI)', 'NOTA\nRECLAMAÇÃO\n(NR)',
#        'OBS PARCEIRA', 'REGIONAL', 'MEDIÇÃO', 'Origem'],
#       dtype='object')
# Colunas excluídas com sucesso!
# Arquivo C:\Users\E1180062\Downloads\Análise de Orçamento\Dados_Combinados_MAR_MET.xlsx lido com sucesso!
# Frequência dos serviços:
#  DESCRIÇÃO DE SERVIÇO
# INST COBERTURA PROVISORIA CONDUTOR 4P LV    156
# PODAR OU CORTAR ARVORE AREA URBANA LM        80
# REAPERTAR ESTRUTURA PRIMARIA 4P LV           73
# SUBSTITUIR ISOLADOR PINO OU PINO 4P LV       57
# SUBSTITUIR CHAVE FUSIVEL 4P LV               53
#                                            ...
# RETIRAR CHAVE FUSIVEL  LM                     1
# INSTALAR CHAVE FUSIVEL 15KV LM                1
# RETIRAR COND ISOLADO AL BT 2#35(35) LM        1
# ARRASTAR MATERIAL C/ TRATOR LM                1
# SUBST ESTR CRUZ AMAR DUP 4P LV                1
# Name: count, Length: 133, dtype: int64
# Arquivo filtrado C:\Users\E1180062\Downloads\Análise de Orçamento\Dados_Combinados_MAR_MET.xlsx:
#                                  PEP&ORDEM&SERVIÇO   PI TIPO TIPO DE MEDIÇÃO  \
# 11    PM-D22.30.7013.TER.LLD0160007405415033000138  NaN  NaN         Custeio
# 14                                             NaN  NaN  NaN         Custeio
# 22                                             NaN  NaN  NaN         Custeio
# 23                                             NaN  NaN  NaN         Custeio
# 24                                             NaN  NaN  NaN         Custeio
# ...                                            ...  ...  ...             ...
# 1472  PM-D23.30.7013.TER.LLD0160007449315033000169  NaN  NaN         Custeio
# 1484            PM-D23.30.7013.TER.LLD015033000131  NaN  NaN         Custeio
# 1487            PM-D23.30.7013.TER.LLD015033000062  NaN  NaN         Custeio
# 1491            PM-D23.30.7013.TER.LLD015033000159  NaN  NaN         Custeio
# 1492            PM-D23.30.7013.TER.LLD015033000169  NaN  NaN         Custeio
#
#      TIPO DE MEDIÇÃO.1              PEP IV NÍVEL STATUS PEP  \
# 11           MED ÚNICA  PM-D22.30.7013.TER.LLD01        NaN
# 14           MED ÚNICA                       NaN        NaN
# 22           MED ÚNICA  PM-D22.30.7013.TER.LLD01        NaN
# 23           MED ÚNICA  PM-D22.30.7013.TER.LLD01        NaN
# 24           MED ÚNICA                       NaN        NaN
# ...                ...                       ...        ...
# 1472         MED ÚNICA  PM-D23.30.7013.TER.LLD01        NaN
# 1484         MED ÚNICA  PM-D23.30.7013.TER.LLD01        NaN
# 1487         MED ÚNICA  PM-D23.30.7013.TER.LLD01        NaN
# 1491         MED ÚNICA  PM-D23.30.7013.TER.LLD01        NaN
# 1492         MED ÚNICA  PM-D23.30.7013.TER.LLD01        NaN
#
#      STATUS PEP\n(ALTERADO) ORDEM/DIAGRAMA STATUS ORDEM/DIAGRAMA  ...  \
# 11                        /     6000740541                   NaN  ...
# 14                      NaN     6000633840                   NaN  ...
# 22                      NaN     6000740543                   NaN  ...
# 23                      NaN     6000740543                   NaN  ...
# 24                      NaN     6000733502                   NaN  ...
# ...                     ...            ...                   ...  ...
# 1472                      /     6000744931                   NaN  ...
# 1484                      /            NaN                   NaN  ...
# 1487                      /            NaN                   NaN  ...
# 1491                      /            NaN                   NaN  ...
# 1492                      /            NaN                   NaN  ...
#
#                MUNICÍPIO DESLOCAMENTO\nDE DESLOCAMENTO\nPARA    EQUIPE  \
# 11              TERESINA         TERESINA           TERESINA  LVLTHE01
# 14              TERESINA         TERESINA           TERESINA  LVLTHE01
# 22              TERESINA         TERESINA           TERESINA  LVLTHE01
# 23              TERESINA         TERESINA           TERESINA  LVLTHE01
# 24              TERESINA         TERESINA           TERESINA  LVPTHE01
# ...                  ...              ...                ...       ...
# 1472  SÃO PEDRO DO PIAUI              NaN                NaN       NaN
# 1484        AGRICOLANDIA              NaN                NaN       NaN
# 1487        AGRICOLANDIA              NaN                NaN       NaN
# 1491        AGRICOLANDIA              NaN                NaN       NaN
# 1492        AGRICOLANDIA              NaN                NaN       NaN
#
#       SOLICITAÇÃO DE\nINTERVENÇÃO\n(SI)  NOTA\nRECLAMAÇÃO\n(NR)  \
# 11                                  NaN               OC-159668
# 14                               346459                     NaN
# 22                                  NaN               OC-163114
# 23                                  NaN               OC-163114
# 24                                  NaN                     NaN
# ...                                 ...                     ...
# 1472                          NDS 3-291                     NaN
# 1484                          SI 348706                     NaN
# 1487                          SI 348706                     NaN
# 1491                          SI 348706                     NaN
# 1492                          SI 348706                     NaN
#
#                                        OBS PARCEIRA REGIONAL  MEDIÇÃO  \
# 11                                CHAVE REUTILIZADA      NaN      NaN
# 14    RETIRADA DE ANOMALIAS PTY01P5 - BASE TERESINA      NaN      NaN
# 22                                              NaN      NaN      NaN
# 23                                              NaN      NaN      NaN
# 24                              PLANO DE MANUTENÇÃO      NaN      NaN
# ...                                             ...      ...      ...
# 1472                                            NaN      NaN      NaN
# 1484                            BY PASS PROVISORIOS      NaN      NaN
# 1487                                            NaN      NaN      NaN
# 1491                                            NaN      NaN      NaN
# 1492                                            NaN      NaN      NaN
#
#                                                  Origem
# 11    C:\Users\E1180062\Downloads\Análise de Orçamen...
# 14    C:\Users\E1180062\Downloads\Análise de Orçamen...
# 22    C:\Users\E1180062\Downloads\Análise de Orçamen...
# 23    C:\Users\E1180062\Downloads\Análise de Orçamen...
# 24    C:\Users\E1180062\Downloads\Análise de Orçamen...
# ...                                                 ...
# 1472  C:\Users\E1180062\Downloads\Análise de Orçamen...
# 1484  C:\Users\E1180062\Downloads\Análise de Orçamen...
# 1487  C:\Users\E1180062\Downloads\Análise de Orçamen...
# 1491  C:\Users\E1180062\Downloads\Análise de Orçamen...
# 1492  C:\Users\E1180062\Downloads\Análise de Orçamen...
#
# [328 rows x 39 columns]
# Frequência dos serviços filtrados:
#  DESCRIÇÃO DE SERVIÇO
# SUBSTITUIR CHAVE FUSIVEL 4P LV              53
# INSTALAR PARA-RAIOS LM                      25
# INSTALAR TRAFO DIST POSTE LM                24
# RETIRAR TRAFO DIST POSTE LM                 23
# RETIRAR PARA-RAIOS 4P LV                    21
# INSTALAR PARA-RAIOS BT LM                   19
# INST CHAVE BY-PASS 4P LV                    18
# INSTALAR PARA-RAIOS 4P LV                   18
# INSTALAR POSTE 10 A 14M LM                  17
# INSTALAR POSTE 7 A 9M LM                    12
# SUBSTITUIR PARA-RAIOS DIST 3P LV            12
# RETIRAR POSTE 7 A 9M FECHAR CAVA LM         12
# RETIRAR POSTE 10 A 14M FECHAR CAVA LM        8
# DESCONECTAR RAMAL LIGACAO 1F/2F              7
# CONECTAR RAMAL LIGACAO 1F/2F LM              7
# APRUMAR POSTE RD LM                          5
# INSTALAR MANILHA FUNDAÇÃO DE POSTE LM        5
# INST CHAVE FACA 4P LV                        5
# RETIRAR CHAVE FUSIVEL 4P LV                  5
# DESCONECTAR RAMAL LIGACAO 1F/2F              4
# INSTALAR CHAVE FUSIVEL 4P LV                 4
# APRUMAR POSTE RD LM                          4
# CONECTAR RAMAL LIGACAO 1F/2F LM              4
# RETIRAR CHAVE FACA 4P LV                     3
# RETIRAR POSTE 7 A 9M FECHAR CAVA LM          2
# RETIRAR CHAVE FUSIVEL RELIGADORA 4P LV       2
# INSTALAR MANILHA FUNDAÇÃO DE POSTE LM        1
# INSTALAR RELIGADOR RD POSTE LM               1
# RETIRAR TRAFO DIST POSTE LM                  1
# INSTALAR CHAVE FUSIVEL 15KV LM               1
# RETIRAR RELIGADOR RD LM                      1
# INSTALAR TRAFO DIST POSTE LM                 1
# RETIRAR PARA-RAIOS LM                        1
# SUBSTITUIR CHAVE FUSIVEL LM                  1
# RETIRAR CHAVE FUSIVEL  LM                    1
# Name: count, dtype: int64
#
# Nomes das colunas após a filtragem:
# Index(['PEP&ORDEM&SERVIÇO', 'PI', 'TIPO', 'TIPO DE MEDIÇÃO',
#        'TIPO DE MEDIÇÃO.1', 'PEP IV NÍVEL', 'STATUS PEP',
#        'STATUS PEP\n(ALTERADO)', 'ORDEM/DIAGRAMA', 'STATUS ORDEM/DIAGRAMA',
#        'NOTA PROJ', 'DESCR. DA OBRA', 'CADERNO', 'ITEM', 'CÓD. SERVIÇO',
#        'CÓD. SERVIÇO&ITEM', 'DESCRIÇÃO DE SERVIÇO', 'UN.', 'PU', 'QUANT / KM',
#        'VALOR', 'QUANT / KM.1', 'VALOR.1', 'TIPO DE MEDIÇÃO.2',
#        'TIPO DE MEDIÇÃO.3', 'TÉCNICO OBRA', 'SUPERVISOR/SOLICITANTE',
#        'PERÍODO DE MEDIÇÃO', 'DATA DO SERVIÇO', 'MUNICÍPIO',
#        'DESLOCAMENTO\nDE', 'DESLOCAMENTO\nPARA', 'EQUIPE',
#        'SOLICITAÇÃO DE\nINTERVENÇÃO\n(SI)', 'NOTA\nRECLAMAÇÃO\n(NR)',
#        'OBS PARCEIRA', 'REGIONAL', 'MEDIÇÃO', 'Origem'],
#       dtype='object')
# Colunas excluídas com sucesso!
# Arquivo C:\Users\E1180062\Downloads\Análise de Orçamento\Dados_Combinados_ABR_MET.xlsx lido com sucesso!
# Frequência dos serviços:
#  DESCRIÇÃO DE SERVIÇO
# INST COBERTURA PROVISORIA CONDUTOR 4P LV    124
# PODAR OU CORTAR ARVORE AREA URBANA LM        76
# REAPERTAR ESTRUTURA PRIMARIA 4P LV           71
# AVISO ENTREGA DE CARTA P/ DESLIG S/ PROT     63
# TURMA LV ATE 36,2KV 4H DISPON                61
#                                            ...
# INST ESTRUTURA EM RDC CE3 4P LV               1
# TENSIONAR CABO MENSAG RDC4P LV                1
# VERIFICAR SEQUENCIA FASE LM                   1
# INST COND COB RD COMPACTA 185MM2 LM           1
# RETIRAR CHAVE BY-PASS 4P LV                   1
# Name: count, Length: 91, dtype: int64
# Arquivo filtrado C:\Users\E1180062\Downloads\Análise de Orçamento\Dados_Combinados_ABR_MET.xlsx:
#                                  PEP&ORDEM&SERVIÇO  PI  TIPO TIPO DE MEDIÇÃO  \
# 8                                              NaN NaN   NaN         Custeio
# 22    PM-D22.30.7013.TER.LLD0160007449205033000169 NaN   NaN         Custeio
# 28                                             NaN NaN   NaN         Custeio
# 34                                             NaN NaN   NaN         Custeio
# 68                                             NaN NaN   NaN         Custeio
# ...                                            ...  ..   ...             ...
# 1011  PM-D23.30.7013.TER.LLD0160007510635033000062 NaN   NaN         Custeio
# 1015  PM-D23.30.7013.TER.LLD0160007510635033000159 NaN   NaN         Custeio
# 1031  PM-D23.30.7013.TER.LLD0160007210755033000153 NaN   NaN         Custeio
# 1032  PM-D23.30.7013.TER.LLD0160007210755033000169 NaN   NaN         Custeio
# 1043  PM-D23.30.7013.TER.LLD0160007570245033000169 NaN   NaN         Custeio
#
#      TIPO DE MEDIÇÃO.1              PEP IV NÍVEL  STATUS PEP  \
# 8            MED ÚNICA  PM-D22.30.7013.TER.LLD01         NaN
# 22           MED ÚNICA  PM-D22.30.7013.TER.LLD01         NaN
# 28           MED ÚNICA  PM-D22.30.7013.TER.LLD01         NaN
# 34           MED ÚNICA  PM-D22.30.7013.TER.LLD01         NaN
# 68           MED ÚNICA                       NaN         NaN
# ...                ...                       ...         ...
# 1011         MED ÚNICA  PM-D23.30.7013.TER.LLD01         NaN
# 1015         MED ÚNICA  PM-D23.30.7013.TER.LLD01         NaN
# 1031         MED ÚNICA  PM-D23.30.7013.TER.LLD01         NaN
# 1032         MED ÚNICA  PM-D23.30.7013.TER.LLD01         NaN
# 1043         MED ÚNICA  PM-D23.30.7013.TER.LLD01         NaN
#
#      STATUS PEP\n(ALTERADO)  ORDEM/DIAGRAMA STATUS ORDEM/DIAGRAMA  ...  \
# 8                       NaN      6000732473                   NaN  ...
# 22                        /      6000744920                   NaN  ...
# 28                      NaN      6000745233                   NaN  ...
# 34                      NaN      6000744922                   NaN  ...
# 68                      NaN      6000746319                   NaN  ...
# ...                     ...             ...                   ...  ...
# 1011                      /      6000751063                   NaN  ...
# 1015                      /      6000751063                   NaN  ...
# 1031                      /      6000721075                   NaN  ...
# 1032                      /      6000721075                   NaN  ...
# 1043                      /      6000757024                   NaN  ...
#
#                MUNICÍPIO    DESLOCAMENTO\nDE  DESLOCAMENTO\nPARA    EQUIPE  \
# 8               TERESINA            TERESINA            TERESINA  MANTHE01
# 22              TERESINA            TERESINA            TERESINA  LVPTHE02
# 28    SAO PEDRO DO PIAUI  SAO PEDRO DO PIAUI  SAO PEDRO DO PIAUI  EXPSPP01
# 34              TERESINA            TERESINA            TERESINA  LVLTHE02
# 68              TERESINA            TERESINA            TERESINA  LVPTHE02
# ...                  ...                 ...                 ...       ...
# 1011  SÃO PEDRO DO PIAUI                 NaN                 NaN       NaN
# 1015  SÃO PEDRO DO PIAUI                 NaN                 NaN       NaN
# 1031      DEMERVAL LOBÃO                 NaN                 NaN       NaN
# 1032      DEMERVAL LOBÃO                 NaN                 NaN       NaN
# 1043         REGENERAÇÃO                 NaN                 NaN       NaN
#
#       SOLICITAÇÃO DE\nINTERVENÇÃO\n(SI)  NOTA\nRECLAMAÇÃO\n(NR) OBS PARCEIRA  \
# 8                                   NaN                     NaN          NaN
# 22                                  NaN                     NaN          NaN
# 28                                  NaN                     NaN          NaN
# 34                                  NaN                     NaN          NaN
# 68                                  NaN                     NaN          NaN
# ...                                 ...                     ...          ...
# 1011                                NaN                     NaN          NaN
# 1015                                NaN                     NaN          NaN
# 1031                                NaN                     NaN          NaN
# 1032                                NaN                     NaN          NaN
# 1043                                NaN                     NaN          NaN
#
#      REGIONAL  MEDIÇÃO                                             Origem
# 8         NaN      NaN  C:\Users\E1180062\Downloads\Análise de Orçamen...
# 22        NaN      NaN  C:\Users\E1180062\Downloads\Análise de Orçamen...
# 28        NaN      NaN  C:\Users\E1180062\Downloads\Análise de Orçamen...
# 34        NaN      NaN  C:\Users\E1180062\Downloads\Análise de Orçamen...
# 68        NaN      NaN  C:\Users\E1180062\Downloads\Análise de Orçamen...
# ...       ...      ...                                                ...
# 1011      NaN      NaN  C:\Users\E1180062\Downloads\Análise de Orçamen...
# 1015      NaN      NaN  C:\Users\E1180062\Downloads\Análise de Orçamen...
# 1031      NaN      NaN  C:\Users\E1180062\Downloads\Análise de Orçamen...
# 1032      NaN      NaN  C:\Users\E1180062\Downloads\Análise de Orçamen...
# 1043      NaN      NaN  C:\Users\E1180062\Downloads\Análise de Orçamen...
#
# [117 rows x 39 columns]
# Frequência dos serviços filtrados:
#  DESCRIÇÃO DE SERVIÇO
# SUBSTITUIR CHAVE FUSIVEL 4P LV              46
# RETIRAR PARA-RAIOS 4P LV                    19
# INSTALAR PARA-RAIOS 4P LV                   18
# APRUMAR POSTE RD LM                          7
# INSTALAR CHAVE FUSIVEL 4P LV                 5
# RETIRAR CHAVE FACA 4P LV                     4
# INSTALAR MANILHA FUNDAÇÃO DE POSTE LM        3
# INST CHAVE FACA 4P LV                        3
# SUBSTITUIR PARA-RAIOS DIST 3P LV             2
# RETIRAR CHAVE FUSIVEL 4P LV                  2
# INSTALAR PARA-RAIOS BT LM                    1
# APRUMAR POSTE RD LM                          1
# TENSIONAR CABO MENSAG RDC4P LV               1
# RETIRAR TRAFO DIST POSTE LM                  1
# RETIRAR CABO MENSAGEIRO RDC 3P LV            1
# INST CHAVE FUSIVEL RELIGADORA 4P LV          1
# RETIRAR CHAVE FUSIVEL RELIGADORA 4P LV       1
# RETIRAR CHAVE BY-PASS 4P LV                  1
# Name: count, dtype: int64
#
# Nomes das colunas após a filtragem:
# Index(['PEP&ORDEM&SERVIÇO', 'PI', 'TIPO', 'TIPO DE MEDIÇÃO',
#        'TIPO DE MEDIÇÃO.1', 'PEP IV NÍVEL', 'STATUS PEP',
#        'STATUS PEP\n(ALTERADO)', 'ORDEM/DIAGRAMA', 'STATUS ORDEM/DIAGRAMA',
#        'NOTA PROJ', 'DESCR. DA OBRA', 'CADERNO', 'ITEM', 'CÓD. SERVIÇO',
#        'CÓD. SERVIÇO&ITEM', 'DESCRIÇÃO DE SERVIÇO', 'UN.', 'PU', 'QUANT / KM',
#        'VALOR', 'QUANT / KM.1', 'VALOR.1', 'TIPO DE MEDIÇÃO.2',
#        'TIPO DE MEDIÇÃO.3', 'TÉCNICO OBRA', 'SUPERVISOR/SOLICITANTE',
#        'PERÍODO DE MEDIÇÃO', 'DATA DO SERVIÇO', 'MUNICÍPIO',
#        'DESLOCAMENTO\nDE', 'DESLOCAMENTO\nPARA', 'EQUIPE',
#        'SOLICITAÇÃO DE\nINTERVENÇÃO\n(SI)', 'NOTA\nRECLAMAÇÃO\n(NR)',
#        'OBS PARCEIRA', 'REGIONAL', 'MEDIÇÃO', 'Origem'],
#       dtype='object')
# Colunas excluídas com sucesso!
# Arquivo C:\Users\E1180062\Downloads\Análise de Orçamento\Dados_Combinados_MAI_MET.xlsx lido com sucesso!
# Frequência dos serviços:
#  DESCRIÇÃO DE SERVIÇO
# INST COBERTURA PROVISORIA CONDUTOR 4P LV    144
# REAPERTAR ESTRUTURA PRIMARIA 4P LV           77
# SUBSTITUIR ISOLADOR PINO OU PINO 4P LV       65
# INST JUMPER OU PASSAGEM NEUTRO 4P LV         55
# INSTALAR ESPACADOR REDE SECUNDARIA LM        52
#                                            ...
# RETIRAR ILUMINACAO PUBLICA LM                 1
# INSTALAR ILUMINACAO PUBLICA LM                1
# TURMA LM LEVE APOIO A OBRAS                   1
# VERIFICAR SEQUENCIA FASE LM                   1
# INST ESTRUTURA EM RDC CE2 4P LV               1
# Name: count, Length: 98, dtype: int64
# Arquivo filtrado C:\Users\E1180062\Downloads\Análise de Orçamento\Dados_Combinados_MAI_MET.xlsx:
#                                 PEP&ORDEM&SERVIÇO  PI  TIPO TIPO DE MEDIÇÃO  \
# 0                                             NaN NaN   NaN         Custeio
# 8                                             NaN NaN   NaN         Custeio
# 11                                            NaN NaN   NaN         Custeio
# 34                                            NaN NaN   NaN         Custeio
# 39                                            NaN NaN   NaN         Custeio
# ..                                            ...  ..   ...             ...
# 902  PM-D23.30.7013.TER.LLD0160007680405033000169 NaN   NaN         Custeio
# 910  PM-D23.30.7013.TER.LLD0160007617375033000062 NaN   NaN         Custeio
# 914  PM-D23.30.7013.TER.LLD0160007617375033000169 NaN   NaN         Custeio
# 918  PM-D23.30.7013.TER.LLD0160007680405033000062 NaN   NaN         Custeio
# 922  PM-D23.30.7013.TER.LLD0160007680405033000159 NaN   NaN         Custeio
#
#     TIPO DE MEDIÇÃO.1              PEP IV NÍVEL  STATUS PEP  \
# 0           MED ÚNICA                       NaN         NaN
# 8           MED ÚNICA  PM-D21.30.0414.TER.LPD01         NaN
# 11          MED ÚNICA                       NaN         NaN
# 34          MED ÚNICA  PM-D22.30.7013.TER.LLD01         NaN
# 39          MED ÚNICA  PM-D22.30.7013.TER.LLD01         NaN
# ..                ...                       ...         ...
# 902         MED ÚNICA  PM-D23.30.7013.TER.LLD01         NaN
# 910         MED ÚNICA  PM-D23.30.7013.TER.LLD01         NaN
# 914         MED ÚNICA  PM-D23.30.7013.TER.LLD01         NaN
# 918         MED ÚNICA  PM-D23.30.7013.TER.LLD01         NaN
# 922         MED ÚNICA  PM-D23.30.7013.TER.LLD01         NaN
#
#     STATUS PEP\n(ALTERADO)  ORDEM/DIAGRAMA  STATUS ORDEM/DIAGRAMA  ...  \
# 0                      NaN      6000716465                    NaN  ...
# 8                        /      6000755532                    NaN  ...
# 11                     NaN      6000755533                    NaN  ...
# 34                     NaN      6000756369                    NaN  ...
# 39                     NaN      6000756370                    NaN  ...
# ..                     ...             ...                    ...  ...
# 902                      /      6000768040                    NaN  ...
# 910                      /      6000761737                    NaN  ...
# 914                      /      6000761737                    NaN  ...
# 918                      /      6000768040                    NaN  ...
# 922                      /      6000768040                    NaN  ...
#
#          MUNICÍPIO DESLOCAMENTO\nDE DESLOCAMENTO\nPARA    EQUIPE  \
# 0         TERESINA         TERESINA           TERESINA  LVLTHE02
# 8         TERESINA         TERESINA           TERESINA  MANTHE01
# 11       SAO PEDRO        SAO PEDRO          SAO PEDRO  EXPSPP01
# 34        TERESINA         TERESINA           TERESINA  LVPTHE01
# 39        TERESINA         TERESINA           TERESINA  LVPTHE01
# ..             ...              ...                ...       ...
# 902  HUGO NAPOLEÃO              NaN                NaN       NaN
# 910     PALMEIRAIS              NaN                NaN       NaN
# 914     PALMEIRAIS              NaN                NaN       NaN
# 918  HUGO NAPOLEÃO              NaN                NaN       NaN
# 922  HUGO NAPOLEÃO              NaN                NaN       NaN
#
#      SOLICITAÇÃO DE\nINTERVENÇÃO\n(SI)  NOTA\nRECLAMAÇÃO\n(NR) OBS PARCEIRA  \
# 0                                  NaN               OC-174084          NaN
# 8                                  NaN               OC-188482          NaN
# 11                                 NaN               OC-186781          NaN
# 34                                 NaN               OC-206828          NaN
# 39                                 NaN               OC-206703          NaN
# ..                                 ...                     ...          ...
# 902                          SI 352045                     NaN          NaN
# 910                          SI 352564                     NaN          NaN
# 914                          SI 352564                     NaN          NaN
# 918                          SI 352563                     NaN          NaN
# 922                          SI 352563                     NaN          NaN
#
#     REGIONAL  MEDIÇÃO                                             Origem
# 0        NaN      NaN  C:\Users\E1180062\Downloads\Análise de Orçamen...
# 8        NaN      NaN  C:\Users\E1180062\Downloads\Análise de Orçamen...
# 11       NaN      NaN  C:\Users\E1180062\Downloads\Análise de Orçamen...
# 34       NaN      NaN  C:\Users\E1180062\Downloads\Análise de Orçamen...
# 39       NaN      NaN  C:\Users\E1180062\Downloads\Análise de Orçamen...
# ..       ...      ...                                                ...
# 902      NaN      NaN  C:\Users\E1180062\Downloads\Análise de Orçamen...
# 910      NaN      NaN  C:\Users\E1180062\Downloads\Análise de Orçamen...
# 914      NaN      NaN  C:\Users\E1180062\Downloads\Análise de Orçamen...
# 918      NaN      NaN  C:\Users\E1180062\Downloads\Análise de Orçamen...
# 922      NaN      NaN  C:\Users\E1180062\Downloads\Análise de Orçamen...
#
# [120 rows x 39 columns]
# Frequência dos serviços filtrados:
#  DESCRIÇÃO DE SERVIÇO
# SUBSTITUIR CHAVE FUSIVEL 4P LV              30
# RETIRAR PARA-RAIOS 4P LV                    20
# INSTALAR PARA-RAIOS 4P LV                   19
# APRUMAR POSTE RD LM                          6
# REAPERTAR E REGULAR CHAVE BY-PASS 4P LV      5
# SUBSTITUIR PARA-RAIOS DIST 3P LV             4
# APRUMAR POSTE RD LM                          4
# TENSIONAR CABO MENSAG RDC4P LV               4
# INSTALAR CHAVE FUSIVEL 4P LV                 4
# RETIRAR CHAVE FUSIVEL 4P LV                  4
# INST CHAVE FACA 4P LV                        3
# RETIRAR CHAVE FACA 4P LV                     3
# INSTALAR MANILHA FUNDAÇÃO DE POSTE LM        3
# RETIRAR POSTE 10 A 14M FECHAR CAVA LM        2
# RETIRAR POSTE 7 A 9M FECHAR CAVA LM          2
# DESCONECTAR RAMAL LIGACAO 1F/2F              1
# RETIRAR TRAFO DIST POSTE LM                  1
# DESCONECTAR RAMAL LIGACAO 1F/2F              1
# CONECTAR RAMAL LIGACAO 1F/2F LM              1
# INSTALAR PARA-RAIOS BT LM                    1
# CONECTAR RAMAL LIGACAO 1F/2F LM              1
# INSTALAR MANILHA FUNDAÇÃO DE POSTE LM        1
# Name: count, dtype: int64
#
# Nomes das colunas após a filtragem:
# Index(['PEP&ORDEM&SERVIÇO', 'PI', 'TIPO', 'TIPO DE MEDIÇÃO',
#        'TIPO DE MEDIÇÃO.1', 'PEP IV NÍVEL', 'STATUS PEP',
#        'STATUS PEP\n(ALTERADO)', 'ORDEM/DIAGRAMA', 'STATUS ORDEM/DIAGRAMA',
#        'NOTA PROJ', 'DESCR. DA OBRA', 'CADERNO', 'ITEM', 'CÓD. SERVIÇO',
#        'CÓD. SERVIÇO&ITEM', 'DESCRIÇÃO DE SERVIÇO', 'UN.', 'PU', 'QUANT / KM',
#        'VALOR', 'QUANT / KM.1', 'VALOR.1', 'TIPO DE MEDIÇÃO.2',
#        'TIPO DE MEDIÇÃO.3', 'TÉCNICO OBRA', 'SUPERVISOR/SOLICITANTE',
#        'PERÍODO DE MEDIÇÃO', 'DATA DO SERVIÇO', 'MUNICÍPIO',
#        'DESLOCAMENTO\nDE', 'DESLOCAMENTO\nPARA', 'EQUIPE',
#        'SOLICITAÇÃO DE\nINTERVENÇÃO\n(SI)', 'NOTA\nRECLAMAÇÃO\n(NR)',
#        'OBS PARCEIRA', 'REGIONAL', 'MEDIÇÃO', 'Origem'],
#       dtype='object')
# Colunas excluídas com sucesso!
# Arquivo C:\Users\E1180062\Downloads\Análise de Orçamento\Dados_Combinados_JUN_MET.xlsx lido com sucesso!
# Frequência dos serviços:
#  DESCRIÇÃO DE SERVIÇO
# INST COBERTURA PROVISORIA CONDUTOR 4P LV    146
# AVISO ENTREGA DE CARTA P/ DESLIG S/ PROT    119
# PODAR OU CORTAR ARVORE AREA URBANA LM       103
# AVISO ENTREGA DE CARTA P/ DESLIG C/ PROT     83
# INSTALAR ESPACADOR REDE SECUNDARIA LM        73
#                                            ...
# RETIRAR ESTRUTURA SECUNDARIA LM               1
# RESTAURAR PASSEIO CIMENTADO LM                1
# INSTALAR ESTAI DE ANCORA RD 3P LM             1
# RETIRAR ESTAI ANCORA RD 3P LM                 1
# EMENDAR CONDUTOR NU 4P LV                     1
# Name: count, Length: 129, dtype: int64
# Arquivo filtrado C:\Users\E1180062\Downloads\Análise de Orçamento\Dados_Combinados_JUN_MET.xlsx:
#                                  PEP&ORDEM&SERVIÇO   PI TIPO TIPO DE MEDIÇÃO  \
# 12                                             NaN  NaN  NaN         Custeio
# 13                                             NaN  NaN  NaN         Custeio
# 14                                             NaN  NaN  NaN         Custeio
# 15                                             NaN  NaN  NaN         Custeio
# 45                                             NaN  NaN  NaN         Custeio
# ...                                            ...  ...  ...             ...
# 1441  PM-D23.30.7013.TER.LLD0160007802575033000159  NaN  NaN         Custeio
# 1443  PM-D23.30.7013.TER.LLD0160007802575033000169  NaN  NaN         Custeio
# 1448  PM-D23.30.7013.TER.LLD0160007802575033000062  NaN  NaN         Custeio
# 1452  PM-D23.30.7013.TER.LLD0160007802575033000159  NaN  NaN         Custeio
# 1453  PM-D23.30.7013.TER.LLD0160007802575033000169  NaN  NaN         Custeio
#
#      TIPO DE MEDIÇÃO.1              PEP IV NÍVEL  STATUS PEP  \
# 12           MED ÚNICA  PM-D22.30.7013.TER.LLD01         NaN
# 13           MED ÚNICA  PM-D22.30.7013.TER.LLD01         NaN
# 14           MED ÚNICA  PM-D22.30.7013.TER.LLD01         NaN
# 15           MED ÚNICA  PM-D22.30.7013.TER.LLD01         NaN
# 45           MED ÚNICA  PM-D22.30.7013.TER.LLD01         NaN
# ...                ...                       ...         ...
# 1441         MED ÚNICA  PM-D23.30.7013.TER.LLD01         NaN
# 1443         MED ÚNICA  PM-D23.30.7013.TER.LLD01         NaN
# 1448         MED ÚNICA  PM-D23.30.7013.TER.LLD01         NaN
# 1452         MED ÚNICA  PM-D23.30.7013.TER.LLD01         NaN
# 1453         MED ÚNICA  PM-D23.30.7013.TER.LLD01         NaN
#
#      STATUS PEP\n(ALTERADO)  ORDEM/DIAGRAMA  STATUS ORDEM/DIAGRAMA  ...  \
# 12                      NaN    6.000736e+09                    NaN  ...
# 13                      NaN    6.000740e+09                    NaN  ...
# 14                      NaN    6.000774e+09                    NaN  ...
# 15                      NaN    6.000752e+09                    NaN  ...
# 45                      NaN    6.000740e+09                    NaN  ...
# ...                     ...             ...                    ...  ...
# 1441                      /    6.000780e+09                    NaN  ...
# 1443                      /    6.000780e+09                    NaN  ...
# 1448                      /    6.000780e+09                    NaN  ...
# 1452                      /    6.000780e+09                    NaN  ...
# 1453                      /    6.000780e+09                    NaN  ...
#
#                MUNICÍPIO    DESLOCAMENTO\nDE     DESLOCAMENTO\nPARA    EQUIPE  \
# 12              TERESINA            TERESINA       AV. DOM SEVERINO  MANEQP01
# 13              TERESINA            TERESINA  AV. BARÃO DE GURGUEIA  MANEQP01
# 14              TERESINA            TERESINA               TERESINA  MANEQP01
# 15               NAZARIA             NAZARIA                NAZÁRIA  MANTHE01
# 45    SAO PEDRO DO PIAUI  SAO PEDRO DO PIAUI         URBANO / RURAL  LVLTHE01
# ...                  ...                 ...                    ...       ...
# 1441             NAZARIA                 NaN                    NaN       NaN
# 1443             NAZARIA                 NaN                    NaN       NaN
# 1448          PALMEIRAIS                 NaN                    NaN       NaN
# 1452          PALMEIRAIS                 NaN                    NaN       NaN
# 1453          PALMEIRAIS                 NaN                    NaN       NaN
#
#       SOLICITAÇÃO DE\nINTERVENÇÃO\n(SI)  NOTA\nRECLAMAÇÃO\n(NR) OBS PARCEIRA  \
# 12                                  NaN                     NaN          NaN
# 13                                  NaN                     NaN          NaN
# 14                                  NaN                     NaN          NaN
# 15                               355352                     NaN          NaN
# 45                               354792                     NaN          NaN
# ...                                 ...                     ...          ...
# 1441                          SI 355394                     NaN          NaN
# 1443                          SI 355394                     NaN          NaN
# 1448                          SI 356542                     NaN          NaN
# 1452                          SI 356542                     NaN          NaN
# 1453                          SI 356542                     NaN          NaN
#
#            REGIONAL  MEDIÇÃO  \
# 12    METROPOLITANA      NaN
# 13    METROPOLITANA      NaN
# 14    METROPOLITANA      NaN
# 15    METROPOLITANA      NaN
# 45    METROPOLITANA      NaN
# ...             ...      ...
# 1441            NaN      NaN
# 1443            NaN      NaN
# 1448            NaN      NaN
# 1452            NaN      NaN
# 1453            NaN      NaN
#
#                                                  Origem
# 12    C:\Users\E1180062\Downloads\Análise de Orçamen...
# 13    C:\Users\E1180062\Downloads\Análise de Orçamen...
# 14    C:\Users\E1180062\Downloads\Análise de Orçamen...
# 15    C:\Users\E1180062\Downloads\Análise de Orçamen...
# 45    C:\Users\E1180062\Downloads\Análise de Orçamen...
# ...                                                 ...
# 1441  C:\Users\E1180062\Downloads\Análise de Orçamen...
# 1443  C:\Users\E1180062\Downloads\Análise de Orçamen...
# 1448  C:\Users\E1180062\Downloads\Análise de Orçamen...
# 1452  C:\Users\E1180062\Downloads\Análise de Orçamen...
# 1453  C:\Users\E1180062\Downloads\Análise de Orçamen...
#
# [271 rows x 39 columns]
# Frequência dos serviços filtrados:
#  DESCRIÇÃO DE SERVIÇO
# SUBSTITUIR CHAVE FUSIVEL 4P LV              33
# RETIRAR PARA-RAIOS 4P LV                    18
# INSTALAR TRAFO DIST POSTE LM                18
# RETIRAR TRAFO DIST POSTE LM                 17
# INSTALAR POSTE 10 A 14M LM                  15
# RETIRAR POSTE 7 A 9M FECHAR CAVA LM         15
# RETIRAR POSTE 10 A 14M FECHAR CAVA LM       15
# INSTALAR PARA-RAIOS LM                      15
# INSTALAR POSTE 7 A 9M LM                    12
# INSTALAR PARA-RAIOS 4P LV                   12
# INSTALAR PARA-RAIOS BT LM                    9
# SUBSTITUIR PARA-RAIOS DIST 3P LV             7
# REAPERTAR E REGULAR CHAVE BY-PASS 4P LV      7
# RETIRAR CHAVE FUSIVEL RELIGADORA 4P LV       6
# DESCONECTAR RAMAL LIGACAO 1F/2F              6
# TENSIONAR CABO MENSAG RDC4P LV               6
# RETIRAR CHAVE FUSIVEL 4P LV                  6
# INSTALAR CHAVE FUSIVEL 4P LV                 6
# CONECTAR RAMAL LIGACAO 1F/2F LM              6
# RETIRAR CHAVE FUSIVEL  LM                    5
# INST CHAVE FUSIVEL RELIGADORA 4P LV          5
# INST CHAVE FACA 4P LV                        4
# INSTALAR CHAVE FUSIVEL 15KV LM               4
# INSTALAR MANILHA FUNDAÇÃO DE POSTE LM        4
# RETIRAR CHAVE FACA 4P LV                     3
# APRUMAR POSTE RD LM                          2
# RETIRAR TRAFO DIST POSTE LM                  2
# APRUMAR POSTE RD LM                          2
# INSTALAR MANILHA FUNDAÇÃO DE POSTE LM        2
# RETIRAR RELIGADOR RD LM                      2
# RETIRAR CHAVE BY-PASS 4P LV                  2
# INSTALAR CABO MENSAGEIRO RD COMPACTA LM      1
# RETIRAR POSTE 7 A 9M FECHAR CAVA LM          1
# INSTALAR RELIGADOR RD POSTE LM               1
# INSTALAR RAMAL CABO MULTIP ATE 16MM² LM      1
# SUBST CABO DE BORNE EM TRAFO 3P LM           1
# Name: count, dtype: int64
#
# Nomes das colunas após a filtragem:
# Index(['PEP&ORDEM&SERVIÇO', 'PI', 'TIPO', 'TIPO DE MEDIÇÃO',
#        'TIPO DE MEDIÇÃO.1', 'PEP IV NÍVEL', 'STATUS PEP',
#        'STATUS PEP\n(ALTERADO)', 'ORDEM/DIAGRAMA', 'STATUS ORDEM/DIAGRAMA',
#        'NOTA PROJ', 'DESCR. DA OBRA', 'CADERNO', 'ITEM', 'CÓD. SERVIÇO',
#        'CÓD. SERVIÇO&ITEM', 'DESCRIÇÃO DE SERVIÇO', 'UN.', 'PU', 'QUANT / KM',
#        'VALOR', 'QUANT / KM.1', 'VALOR.1', 'TIPO DE MEDIÇÃO.2',
#        'TIPO DE MEDIÇÃO.3', 'TÉCNICO OBRA', 'SUPERVISOR/SOLICITANTE',
#        'PERÍODO DE MEDIÇÃO', 'DATA DO SERVIÇO', 'MUNICÍPIO',
#        'DESLOCAMENTO\nDE', 'DESLOCAMENTO\nPARA', 'EQUIPE',
#        'SOLICITAÇÃO DE\nINTERVENÇÃO\n(SI)', 'NOTA\nRECLAMAÇÃO\n(NR)',
#        'OBS PARCEIRA', 'REGIONAL', 'MEDIÇÃO', 'Origem'],
#       dtype='object')
# Colunas excluídas com sucesso!
# Dados unificados com sucesso!

# %%
# Salvando o resultado em uma nova planilha
novo_output_file = r'C:\Users\E1180062\Downloads\Análise de Orçamento\Dados Unificados Regionais\Dados_Unificados_MET.xlsx'
try:
    df_unificado.to_excel(novo_output_file, index=False, sheet_name="MET")
    print(f"\nArquivo salvo com sucesso em: {novo_output_file}")
except Exception as e:
    print(f"Erro ao salvar o arquivo: {e}")
# Out:
# Arquivo salvo com sucesso em: C:\Users\E1180062\Downloads\Análise de Orçamento\Dados_Unificados_MET.xlsx
